# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('customer.csv')

# %%
df = df.iloc[:,2:]

# %%
df.head()
# Out:
#     review education purchased
# 0  Average    School        No
# 1     Poor        UG        No
# 2     Good        PG        No
# 3     Good        PG        No
# 4  Average        UG        No

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(df.iloc[:,0:2],df.iloc[:,-1],test_size=0.2)

# %%
X_train
# Out:
#      review education
# 27     Poor        PG
# 4   Average        UG
# 25     Good    School
# 14     Poor        PG
# 49     Good        UG
# 36     Good        UG
# 33     Good        PG
# 2      Good        PG
# 0   Average    School
# 24  Average        PG
# 12     Poor    School
# 34  Average    School
# 18     Good    School
# 45     Poor        PG
# 11     Good        UG
# 7      Poor    School
# 37  Average        PG
# 28     Poor    School
# 44  Average        UG
# 5   Average    School
# 23     Good    School
# 20  Average    School
# 38     Good    School
# 29  Average        UG
# 31     Poor    School
# 35     Poor    School
# 1      Poor        UG
# 39     Poor        PG
# 9      Good        UG
# 10     Good        UG
# 42     Good        PG
# 41     Good        PG
# 48     Good        UG
# 30  Average        UG
# 21  Average        PG
# 22     Poor        PG
# 26     Poor        PG
# 40     Good    School
# 32  Average        UG
# 13  Average    School

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder(categories=[['Poor','Average','Good'],['School','UG','PG']])

# %%
oe.fit(X_train)
# Out:
# OrdinalEncoder(categories=[['Poor', 'Average', 'Good'], ['School', 'UG', 'PG']])

# %%
X_train = oe.transform(X_train)
X_test = oe.transform(X_test)
# Out:
# C:\Users\abhij\OneDrive\Desktop\python\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but OrdinalEncoder was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 X_train = oe.transform(X_train)
#       2 X_test = oe.transform(X_test)
#
# File ~\OneDrive\Desktop\python\Lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~\OneDrive\Desktop\python\Lib\site-packages\sklearn\preprocessing\_encoders.py:1573, in OrdinalEncoder.transform(self, X)
#    1559 def transform(self, X):
#    1560     """
#    1561     Transform X to ordinal codes.
#    1562
#    (...)
#    1571         Transformed input.
#    1572     """
# -> 1573     X_int, X_mask = self._transform(
#    1574         X,
#    1575         handle_unknown=self.handle_unknown,
#    1576         force_all_finite="allow-nan",
#    1577         ignore_category_indices=self._missing_indices,
#    1578     )
#    1579     X_trans = X_int.astype(self.dtype, copy=False)
#    1581     for cat_idx, missing_idx in self._missing_indices.items():
#
# File ~\OneDrive\Desktop\python\Lib\site-packages\sklearn\preprocessing\_encoders.py:191, in _BaseEncoder._transform(self, X, handle_unknown, force_all_finite, warn_on_unknown, ignore_category_indices)
#     189 for i in range(n_features):
#     190     Xi = X_list[i]
# --> 191     diff, valid_mask = _check_unknown(Xi, self.categories_[i], return_mask=True)
#     193     if not np.all(valid_mask):
#     194         if handle_unknown == "error":
#
# File ~\OneDrive\Desktop\python\Lib\site-packages\sklearn\utils\_encode.py:304, in _check_unknown(values, known_values, return_mask)
#     301         valid_mask = np.ones(len(values), dtype=bool)
#     303 # check for nans in the known_values
# --> 304 if np.isnan(known_values).any():
#     305     diff_is_nan = np.isnan(diff)
#     306     if diff_is_nan.any():
#     307         # removes nan from valid_mask
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
