# %%
import concurrent.futures
import collections
import math
import os
import pathlib
import random
import re
import string
import time
import shutil
import pickle

import einops
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from PIL import Image
import tqdm

import tensorflow as tf
#tf.config.run_functions_eagerly(True)

import tensorflow_hub as hub
import tensorflow_text as text
import tensorflow_datasets as tfds

# %%
def load_dataset(save_path, batch_size=32, shuffle=1000, cycle_length=2):
    def custom_reader_func(datasets):
        datasets = datasets.shuffle(1000)
        return datasets.interleave(lambda x: x, cycle_length=cycle_length)

    ds = tf.data.Dataset.load(save_path, reader_func=custom_reader_func)
    
    def drop_index(i, x):
        return x
    
    ds = (ds
        .map(drop_index, tf.data.AUTOTUNE)
        .shuffle(shuffle)
        .padded_batch(batch_size)
        .prefetch(tf.data.AUTOTUNE))
    return ds

# %%
train_ds = load_dataset(str(pathlib.Path.cwd() / 'Model_Data/train_cache'))
test_ds = load_dataset(str(pathlib.Path.cwd() / 'Model_Data/test_cache'))

# %%
class SeqEmbedding(tf.keras.layers.Layer):
    def __init__(self, vocab_size, max_length, depth):
        super().__init__()
        self.pos_embedding = tf.keras.layers.Embedding(input_dim=max_length, output_dim=depth)
        
        self.token_embedding = tf.keras.layers.Embedding(
            input_dim=vocab_size,
            output_dim=depth,
            mask_zero=True)
        
        self.add = tf.keras.layers.Add()
    
    def call(self, seq):
        seq = self.token_embedding(seq) # (batch, seq, depth)
        
        x = tf.range(tf.shape(seq)[1])  # (seq)
        x = x[tf.newaxis, :]  # (1, seq)
        x = self.pos_embedding(x)  # (1, seq, depth)
        
        return self.add([seq, x])


class BaseAttention(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super().__init__()
        self.mha = tf.keras.layers.MultiHeadAttention(**kwargs)
        self.layernorm = tf.keras.layers.LayerNormalization()
        self.add = tf.keras.layers.Add()


class CausalSelfAttention(BaseAttention):
    def call(self, x):
        attn = self.mha(query=x, value=x,
                        use_causal_mask=True)
        x = self.add([x, attn])
        return self.layernorm(x)


class CrossAttention(BaseAttention):
    def call(self, x, y, **kwargs):
        attn, attention_scores = self.mha(
                 query=x, value=y,
                 return_attention_scores=True)
        
        self.last_attention_scores = attention_scores
        
        x = self.add([x, attn])
        return self.layernorm(x)


class FeedForward(tf.keras.layers.Layer):
    def __init__(self, units, dropout_rate=0.1):
        super().__init__()
        self.seq = tf.keras.Sequential([
            tf.keras.layers.Dense(units=2*units, activation='relu'),
            tf.keras.layers.Dense(units=units),
            tf.keras.layers.Dropout(rate=dropout_rate),
        ])
        self.add = tf.keras.layers.Add()
        self.layernorm = tf.keras.layers.LayerNormalization()
    
    def call(self, x):
        x = self.add([x, self.seq(x)])
        return self.layernorm(x)


class DecoderLayer(tf.keras.layers.Layer):
    def __init__(self, units, num_heads=1, dropout_rate=0.1):
        super().__init__()
        
        self.self_attention = CausalSelfAttention(num_heads=num_heads,
                                                  key_dim=units,
                                                  dropout=dropout_rate)
        self.cross_attention = CrossAttention(num_heads=num_heads,
                                              key_dim=units,
                                              dropout=dropout_rate)
        self.ff = FeedForward(units=units, dropout_rate=dropout_rate)
    
    
    def call(self, inputs, training=False):
        in_seq, out_seq = inputs
        
        # Text input
        out_seq = self.self_attention(out_seq)
        out_seq = self.cross_attention(out_seq, in_seq)
        self.last_attention_scores = self.cross_attention.last_attention_scores
        out_seq = self.ff(out_seq)
        return out_seq

# %%
class TokenOutput(tf.keras.layers.Layer):
    def __init__(self, tokenizer, banned_tokens=('', '[UNK]', '[START]'), **kwargs):
        super().__init__()
        
        self.dense = tf.keras.layers.Dense(
            units=tokenizer.vocabulary_size(), **kwargs)
        self.tokenizer = tokenizer
        self.banned_tokens = banned_tokens
        self.bias = None
    
    def adapt(self, ds):
        counts = collections.Counter()
        vocab_dict = {name: id 
                      for id, name in enumerate(self.tokenizer.get_vocabulary())}
    
        for tokens in tqdm.tqdm(ds):
            counts.update(tokens.numpy().flatten())
        
        counts_arr = np.zeros(shape=(self.tokenizer.vocabulary_size(),))
        counts_arr[np.array(list(counts.keys()), dtype=np.int32)] = list(counts.values())
        
        counts_arr = counts_arr[:]
        for token in self.banned_tokens:
            counts_arr[vocab_dict[token]] = 0
        
        total = counts_arr.sum()
        p = counts_arr/total
        p[counts_arr==0] = 1.0
        log_p = np.log(p)  # log(1) == 0
        
        entropy = -(log_p*p).sum()
        
        print()
        print(f"Uniform entropy: {np.log(self.tokenizer.vocabulary_size()):0.2f}")
        print(f"Marginal entropy: {entropy:0.2f}")
        
        self.bias = log_p
        self.bias[counts_arr==0] = -1e9

        pickle.dump(self.bias, open(str(pathlib.Path.cwd() / 'Model_Data/bias.pkl'), 'wb'))
        
    
    def call(self, x):
        x = self.dense(x)
        return x + self.bias

# %%
def standardize(s):
    s = tf.strings.lower(s)
    s = tf.strings.regex_replace(s, f'[{re.escape(string.punctuation)}]', '')
    s = tf.strings.join(['[START]', s, '[END]'], separator=' ')
    return s


from_disk = pickle.load(open(str(pathlib.Path.cwd() / 'Model_Data/tokenizer.pkl'), "rb"))
tokenizer = tf.keras.layers.TextVectorization(
    max_tokens=from_disk['config']['max_tokens'],
    standardize=standardize,
    ragged=True)
tokenizer.set_weights(from_disk['weights'])

# %%
output_layer = TokenOutput(tokenizer, banned_tokens=('', '[UNK]', '[START]'))
output_layer.adapt(train_ds.map(lambda inputs, labels: labels))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 938/938 [00:26<00:00, 36.05it/s]
# Uniform entropy: 8.52
# Marginal entropy: 5.29

# %%
class Captioner(tf.keras.Model):
    @classmethod
    def add_method(cls, fun):
        setattr(cls, fun.__name__, fun)
        return fun
    
    def __init__(self, tokenizer, feature_extractor, output_layer, num_layers=5,
               units=512, max_length=50, num_heads=3, dropout_rate=0.2):
        super().__init__()
        self.feature_extractor = feature_extractor
        self.tokenizer = tokenizer
        self.word_to_index = tf.keras.layers.StringLookup(
            mask_token="",
            vocabulary=tokenizer.get_vocabulary())
        self.index_to_word = tf.keras.layers.StringLookup(
            mask_token="",
            vocabulary=tokenizer.get_vocabulary(),
            invert=True) 
        
        self.seq_embedding = SeqEmbedding(
            vocab_size=tokenizer.vocabulary_size(),
            depth=units,
            max_length=max_length)
        
        self.decoder_layers = [
            DecoderLayer(units, num_heads=num_heads, dropout_rate=dropout_rate)
            for n in range(num_layers)]
        
        self.output_layer = output_layer


@Captioner.add_method
def call(self, inputs):
    image, txt = inputs

    if image.shape[-1] == 3:
      # Apply the feature-extractor, if you get an RGB image.
        image = self.feature_extractor(image)
    
    # Flatten the feature map
    image = einops.rearrange(image, 'b h w c -> b (h w) c')
    
    
    if txt.dtype == tf.string:
      # Apply the tokenizer if you get string inputs.
        txt = tokenizer(txt)
    
    txt = self.seq_embedding(txt)
    
    # Look at the image
    for dec_layer in self.decoder_layers:
        txt = dec_layer(inputs=(image, txt))
    
    txt = self.output_layer(txt)
    
    return txt

# %%
IMAGE_SHAPE=(224, 224, 3)
mobilenet = tf.keras.applications.MobileNetV3Large(
    input_shape=IMAGE_SHAPE,
    include_top=False,
    include_preprocessing=True)
mobilenet.trainable=False
'''
if not os.path.exists(pathlib.Path.cwd() / 'Model_Data'):
    os.mkdir(pathlib.Path.cwd() / 'Model_Data')
shutil.move(pathlib.Path.home() / '.keras/models/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5', pathlib.Path.cwd() / 'Model_Data/mobilenet_v3_large_weights.h5')
'''
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5
# 12683000/12683000 [==============================] - 11s 1us/step
# "\nif not os.path.exists(pathlib.Path.cwd() / 'Model_Data'):\n    os.mkdir(pathlib.Path.cwd() / 'Model_Data')\nshutil.move(pathlib.Path.home() / '.keras/models/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5', pathlib.Path.cwd() / 'Model_Data/mobilenet_v3_large_weights.h5')\n"

# %%
model = Captioner(tokenizer, feature_extractor=mobilenet, output_layer=output_layer,
                  units=512, dropout_rate=0.4, num_layers=5, num_heads=3)

# %%
@Captioner.add_method
def simple_gen(self, image, temperature=1):
    initial = self.word_to_index([['[START]']]) # (batch, sequence)
    img_features = self.feature_extractor(image[tf.newaxis, ...])
    
    tokens = initial # (batch, sequence)
    for n in range(50):
        preds = self((img_features, tokens)).numpy()  # (batch, sequence, vocab)
        preds = preds[:,-1, :]  #(batch, vocab)
        if temperature==0:
            next = tf.argmax(preds, axis=-1)[:, tf.newaxis]  # (batch, 1)
        else:
            next = tf.random.categorical(preds/temperature, num_samples=1)  # (batch, 1)
        tokens = tf.concat([tokens, next], axis=1) # (batch, sequence) 
        
        if next[0] == self.word_to_index('[END]'):
            break
    words = self.index_to_word(tokens[0, 1:-1])
    result = tf.strings.reduce_join(words, axis=-1, separator=' ')
    return result.numpy().decode()

# %%
def masked_loss(labels, preds):  
    loss = tf.nn.sparse_softmax_cross_entropy_with_logits(labels, preds)
    
    mask = (labels != 0) & (loss < 1e8) 
    mask = tf.cast(mask, loss.dtype)
    
    loss = loss*mask
    loss = tf.reduce_sum(loss)/tf.reduce_sum(mask)
    return loss

def masked_acc(labels, preds):
    mask = tf.cast(labels!=0, tf.float32)
    preds = tf.argmax(preds, axis=-1)
    labels = tf.cast(labels, tf.int64)
    match = tf.cast(preds == labels, mask.dtype)
    acc = tf.reduce_sum(match*mask)/tf.reduce_sum(mask)
    return acc

# %%
def load_image(image_path):
    img = tf.io.read_file(image_path)
    img = tf.io.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMAGE_SHAPE[:-1])
    return img

# %%
class GenerateText(tf.keras.callbacks.Callback):
    def __init__(self):
        path = pathlib.Path.cwd() / 'Model_Data'
        image_url = 'https://tensorflow.org/images/surf.jpg'
        image_path = tf.keras.utils.get_file('surf.jpg', origin=image_url, cache_dir=path, cache_subdir=(path / 'train_check'))
        self.image = load_image(image_path)
    
    def on_epoch_end(self, epochs=None, logs=None):
        print()
        print()
        for t in (0.0, 0.5, 1.0):
            result = self.model.simple_gen(self.image, temperature=t)
            print(result)
        print()

# %%
model_save = pathlib.Path.cwd() / 'Model_Data/weights/model.tf'

# %%
callbacks = [
    GenerateText(),
    tf.keras.callbacks.EarlyStopping(
        patience=3, restore_best_weights=True),
    tf.keras.callbacks.ModelCheckpoint(
        model_save, verbose=1, monitor='val_masked_acc', mode='max', save_best_only=True, save_weights_only=True, save_format='tf')]

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
           loss=masked_loss,
           metrics=[masked_acc])

# %%
history = model.fit(
    train_ds.repeat(),
    steps_per_epoch=100,
    validation_data=test_ds.repeat(),
    validation_steps=20,
    epochs=100,
    callbacks=callbacks)
# Out:
# Epoch 1/100
# 100/100 [==============================] - ETA: 0s - loss: 4.7619 - masked_acc: 0.2295
#
# a man in a red in a blue in a water
# a man in a red in a blue into a blue
# a tall door in a sit in the adults
#
#
# Epoch 1: val_masked_acc improved from -inf to 0.28380, saving model to D:\Projects\Image_Caption\Image-Caption\Model\Model_Data\weights\model.tf
# 100/100 [==============================] - 63s 545ms/step - loss: 4.7619 - masked_acc: 0.2295 - val_loss: 4.2854 - val_masked_acc: 0.2838
# Epoch 2/100
# 100/100 [==============================] - ETA: 0s - loss: 4.2464 - masked_acc: 0.2925
#
# a man is jumping in the water
# a person is riding a yellow pool
# a tails boy is wearing the water with a stick in the walks
#
#
# Epoch 2: val_masked_acc improved from 0.28380 to 0.31691, saving model to D:\Projects\Image_Caption\Image-Caption\Model\Model_Data\weights\model.tf
# 100/100 [==============================] - 56s 565ms/step - loss: 4.2464 - masked_acc: 0.2925 - val_loss: 3.9532 - val_masked_acc: 0.3169
# Epoch 3/100
# 100/100 [==============================] - ETA: 0s - loss: 4.0267 - masked_acc: 0.3180
#
# a man in a blue shirt is riding a blue water
# a man in a blue is jumping in the water
# a boys next down the ocean
#
#
# Epoch 3: val_masked_acc improved from 0.31691 to 0.33142, saving model to D:\Projects\Image_Caption\Image-Caption\Model\Model_Data\weights\model.tf
# 100/100 [==============================] - 53s 532ms/step - loss: 4.0267 - masked_acc: 0.3180 - val_loss: 3.7947 - val_masked_acc: 0.3314
# Epoch 4/100
# 100/100 [==============================] - ETA: 0s - loss: 3.8495 - masked_acc: 0.3320
#
# a man is jumping on a wave
# a man is in a swimming is in front of a wave
# seaweed boy suits wearing a pink shirt are children is playing off a large skateboard
#
#
# Epoch 4: val_masked_acc improved from 0.33142 to 0.34913, saving model to D:\Projects\Image_Caption\Image-Caption\Model\Model_Data\weights\model.tf
# 100/100 [==============================] - 55s 551ms/step - loss: 3.8495 - masked_acc: 0.3320 - val_loss: 3.6074 - val_masked_acc: 0.3491
# Epoch 5/100
# 100/100 [==============================] - ETA: 0s - loss: 3.7351 - masked_acc: 0.3412
#
# a man is jumping over a wave
# a man in a red coat is wearing a red shirt is swimming wave
# a girl in a coat is wearing a light fenced wave
#
#
# Epoch 5: val_masked_acc improved from 0.34913 to 0.35439, saving model to D:\Projects\Image_Caption\Image-Caption\Model\Model_Data\weights\model.tf
# 100/100 [==============================] - 58s 583ms/step - loss: 3.7351 - masked_acc: 0.3412 - val_loss: 3.5140 - val_masked_acc: 0.3544
# Epoch 6/100
# 100/100 [==============================] - ETA: 0s - loss: 3.6540 - masked_acc: 0.3524
#
# a man in a red shirt is riding a wave
# a man is wearing a red and a white shirt is playing a wave
# a girl has someone in a wave that while the rapids
#
#
# Epoch 6: val_masked_acc improved from 0.35439 to 0.35736, saving model to D:\Projects\Image_Caption\Image-Caption\Model\Model_Data\weights\model.tf
# 100/100 [==============================] - 55s 555ms/step - loss: 3.6540 - masked_acc: 0.3524 - val_loss: 3.4716 - val_masked_acc: 0.3574
# Epoch 7/100
# 100/100 [==============================] - ETA: 0s - loss: 3.5257 - masked_acc: 0.3618
#
# a man is riding a wave on a wave
# a person is on a wave
# a man jumps a air
#
#
# Epoch 7: val_masked_acc improved from 0.35736 to 0.36199, saving model to D:\Projects\Image_Caption\Image-Caption\Model\Model_Data\weights\model.tf
# 100/100 [==============================] - 52s 519ms/step - loss: 3.5257 - masked_acc: 0.3618 - val_loss: 3.4446 - val_masked_acc: 0.3620
# Epoch 8/100
# 100/100 [==============================] - ETA: 0s - loss: 3.4687 - masked_acc: 0.3658
#
# a man in a red shirt is riding a wave
# a girl in a blue shirt is riding a wave
# a person in a resting batsman on an wave in the small toy in the wave
#
#
# Epoch 8: val_masked_acc improved from 0.36199 to 0.37005, saving model to D:\Projects\Image_Caption\Image-Caption\Model\Model_Data\weights\model.tf
# 100/100 [==============================] - 63s 636ms/step - loss: 3.4687 - masked_acc: 0.3658 - val_loss: 3.3148 - val_masked_acc: 0.3700
# Epoch 9/100
# 100/100 [==============================] - ETA: 0s - loss: 3.4000 - masked_acc: 0.3755
#
# a man in a red shirt is riding a wave
# a man is riding a yellow wave
# a person shore into the high through the wave
#
#
# Epoch 9: val_masked_acc did not improve from 0.37005
# 100/100 [==============================] - 59s 592ms/step - loss: 3.4000 - masked_acc: 0.3755 - val_loss: 3.3164 - val_masked_acc: 0.3699
# Epoch 10/100
# 100/100 [==============================] - ETA: 0s - loss: 3.3210 - masked_acc: 0.3763
#
# a man in a red shirt is riding a wave
# a surfer jumps into the water
# a kid is running down is young wave
#
#
# Epoch 10: val_masked_acc improved from 0.37005 to 0.38108, saving model to D:\Projects\Image_Caption\Image-Caption\Model\Model_Data\weights\model.tf
# 100/100 [==============================] - 57s 572ms/step - loss: 3.3210 - masked_acc: 0.3763 - val_loss: 3.2120 - val_masked_acc: 0.3811
# Epoch 11/100
# 100/100 [==============================] - ETA: 0s - loss: 3.2103 - masked_acc: 0.3895
#
# a man in a red shirt is riding a wave
# a man in a red wetsuit is riding a wave
# a small girl in a stands on the beach
#
#
# Epoch 11: val_masked_acc did not improve from 0.38108
# 100/100 [==============================] - 57s 568ms/step - loss: 3.2103 - masked_acc: 0.3895 - val_loss: 3.2019 - val_masked_acc: 0.3791
# Epoch 12/100
# 100/100 [==============================] - ETA: 0s - loss: 3.1593 - masked_acc: 0.3898
#
# a surfer is riding a wave
# a person is being wave in the ocean
# a girl is jumping through the water
#
#
# Epoch 12: val_masked_acc did not improve from 0.38108
# 100/100 [==============================] - 54s 538ms/step - loss: 3.1593 - masked_acc: 0.3898 - val_loss: 3.2064 - val_masked_acc: 0.3781
# Epoch 13/100
# 100/100 [==============================] - ETA: 0s - loss: 3.1227 - masked_acc: 0.3999
#
# a man in a red wetsuit is riding a wave
# a man in a red wetsuit is riding a wave
# a surfer does a blue off the air
#
#
# Epoch 13: val_masked_acc improved from 0.38108 to 0.38480, saving model to D:\Projects\Image_Caption\Image-Caption\Model\Model_Data\weights\model.tf
# 100/100 [==============================] - 53s 533ms/step - loss: 3.1227 - masked_acc: 0.3999 - val_loss: 3.1183 - val_masked_acc: 0.3848
# Epoch 14/100
# 100/100 [==============================] - ETA: 0s - loss: 3.1301 - masked_acc: 0.3914
#
# a surfer is riding a wave
# a man in a red wetsuit is riding a wave
# a fruit is fishing splashing in the strange tires in the ocean
#
#
# Epoch 14: val_masked_acc improved from 0.38480 to 0.38785, saving model to D:\Projects\Image_Caption\Image-Caption\Model\Model_Data\weights\model.tf
# 100/100 [==============================] - 59s 595ms/step - loss: 3.1301 - masked_acc: 0.3914 - val_loss: 3.1095 - val_masked_acc: 0.3879
# Epoch 15/100
# 100/100 [==============================] - ETA: 0s - loss: 3.1162 - masked_acc: 0.3945
#
# a surfer in a red wetsuit is riding a wave
# a man rides a wave
# the surfer arm on his wave
#
#
# Epoch 15: val_masked_acc improved from 0.38785 to 0.38927, saving model to D:\Projects\Image_Caption\Image-Caption\Model\Model_Data\weights\model.tf
# 100/100 [==============================] - 54s 540ms/step - loss: 3.1162 - masked_acc: 0.3945 - val_loss: 3.0812 - val_masked_acc: 0.3893
# Epoch 16/100
# 100/100 [==============================] - ETA: 0s - loss: 3.0545 - masked_acc: 0.3986
#
# a man is riding a wave
# a man is surfing on a surfboard while a man is riding a wave
# a man rides a wave on a lake
#
#
# Epoch 16: val_masked_acc did not improve from 0.38927
# 100/100 [==============================] - 58s 578ms/step - loss: 3.0545 - masked_acc: 0.3986 - val_loss: 3.0525 - val_masked_acc: 0.3816
# Epoch 17/100
# 100/100 [==============================] - ETA: 0s - loss: 3.0517 - masked_acc: 0.4026
#
# a surfer in a red wetsuit is riding a wave
# a man in a red wetsuit is running through the ocean
# a person in kayak is riding his chased emerges
#
#
# Epoch 17: val_masked_acc improved from 0.38927 to 0.39867, saving model to D:\Projects\Image_Caption\Image-Caption\Model\Model_Data\weights\model.tf
# 100/100 [==============================] - 58s 584ms/step - loss: 3.0517 - masked_acc: 0.4026 - val_loss: 2.9717 - val_masked_acc: 0.3987
# Epoch 18/100
# 100/100 [==============================] - ETA: 0s - loss: 3.0016 - masked_acc: 0.4036
#
# a man is riding a wave on a wave
# a man is riding a surfboard on a surfboard
# a surfer on a wave jumps over the tethered of a wave
#
#
# Epoch 18: val_masked_acc did not improve from 0.39867
# 100/100 [==============================] - 54s 545ms/step - loss: 3.0016 - masked_acc: 0.4036 - val_loss: 3.0295 - val_masked_acc: 0.3919
# Epoch 19/100
# 100/100 [==============================] - ETA: 0s - loss: 2.9568 - masked_acc: 0.4090
#
# a man in a red wetsuit is riding a wave
# a surfer rides a surfboard on the wave
# white surfboard on a wave in waves
#
#
# Epoch 19: val_masked_acc improved from 0.39867 to 0.40142, saving model to D:\Projects\Image_Caption\Image-Caption\Model\Model_Data\weights\model.tf
# 100/100 [==============================] - 63s 631ms/step - loss: 2.9568 - masked_acc: 0.4090 - val_loss: 2.9497 - val_masked_acc: 0.4014
# Epoch 20/100
# 100/100 [==============================] - ETA: 0s - loss: 2.8436 - masked_acc: 0.4198
#
# a man in a red wetsuit is riding a wave
# a man is riding a surfboard on a wave
# the surfer is in the trunks is surfs pulled on the beach
#
#
# Epoch 20: val_masked_acc did not improve from 0.40142
# 100/100 [==============================] - 56s 561ms/step - loss: 2.8436 - masked_acc: 0.4198 - val_loss: 3.0231 - val_masked_acc: 0.3895
# Epoch 21/100
# 100/100 [==============================] - ETA: 0s - loss: 2.8229 - masked_acc: 0.4232
#
# a surfer is riding a wave
# a man in a red wetsuit is riding a wave
# a bike jumps
#
#
# Epoch 21: val_masked_acc did not improve from 0.40142
# 100/100 [==============================] - 55s 551ms/step - loss: 2.8229 - masked_acc: 0.4232 - val_loss: 2.9868 - val_masked_acc: 0.3951
# Epoch 22/100
# 100/100 [==============================] - ETA: 0s - loss: 2.8083 - masked_acc: 0.4238
#
# a man is riding a yellow surfboard
# a surfer is riding a surfboard
# a six climber diving in the sea
#
#
# Epoch 22: val_masked_acc did not improve from 0.40142
# 100/100 [==============================] - 57s 568ms/step - loss: 2.8083 - masked_acc: 0.4238 - val_loss: 2.9478 - val_masked_acc: 0.3945
# Epoch 23/100
# 100/100 [==============================] - ETA: 0s - loss: 2.7860 - masked_acc: 0.4260
#
# a surfer in a red wetsuit is riding a wave
# a man on a surfboard is riding a yellow surfboard
# a surfer on a wave with a white wave on a wave
#
#
# Epoch 23: val_masked_acc did not improve from 0.40142
# 100/100 [==============================] - 58s 577ms/step - loss: 2.7860 - masked_acc: 0.4260 - val_loss: 2.9013 - val_masked_acc: 0.4013
# Epoch 24/100
# 100/100 [==============================] - ETA: 0s - loss: 2.7761 - masked_acc: 0.4268
#
# a man is riding a wave on a surfboard
# a man is surfing a wave in the ocean
# man pool crashing near the ocean covered wave
#
#
# Epoch 24: val_masked_acc did not improve from 0.40142
# 100/100 [==============================] - 59s 591ms/step - loss: 2.7761 - masked_acc: 0.4268 - val_loss: 2.9169 - val_masked_acc: 0.3977
# Epoch 25/100
# 100/100 [==============================] - ETA: 0s - loss: 2.7544 - masked_acc: 0.4293
#
# a surfer in a red wetsuit is surfing
# a man on a surfboard is surfing
# a surfer on a wave
#
#
# Epoch 25: val_masked_acc improved from 0.40142 to 0.40194, saving model to D:\Projects\Image_Caption\Image-Caption\Model\Model_Data\weights\model.tf
# 100/100 [==============================] - 68s 687ms/step - loss: 2.7544 - masked_acc: 0.4293 - val_loss: 2.9459 - val_masked_acc: 0.4019
# Epoch 26/100
# 100/100 [==============================] - ETA: 0s - loss: 2.7565 - masked_acc: 0.4284
#
# a man in a red wetsuit rides a wave
# a surfer is surfing on a wave
# a surfer in a kayak catching a jet wave over top of a wave
#
#
# Epoch 26: val_masked_acc improved from 0.40194 to 0.40291, saving model to D:\Projects\Image_Caption\Image-Caption\Model\Model_Data\weights\model.tf
# 100/100 [==============================] - 73s 736ms/step - loss: 2.7565 - masked_acc: 0.4284 - val_loss: 2.9077 - val_masked_acc: 0.4029

# %%
result = model.simple_gen(load_image(str(pathlib.Path.cwd() / 'Model_Data/train_check/surf.jpg')), temperature=0.0)
result
# Out:
# 'a surfer in a red wetsuit is riding a wave'

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.ylim([0, max(plt.ylim())])
plt.xlabel('Epoch #')
plt.ylabel('CE/token')
plt.legend()

# %%
plt.plot(history.history['masked_acc'], label='accuracy')
plt.plot(history.history['val_masked_acc'], label='val_accuracy')
plt.ylim([0, max(plt.ylim())])
plt.xlabel('Epoch #')
plt.ylabel('CE/token')
plt.legend()

# %%
def plot_attention_maps(image, str_tokens, attention_map):
    fig = plt.figure(figsize=(16, 9))

    len_result = len(str_tokens)

    titles = []
    for i in range(len_result):
      map = attention_map[i]
      grid_size = max(int(np.ceil(len_result/2)), 2)
      ax = fig.add_subplot(3, grid_size, i+1)
      titles.append(ax.set_title(str_tokens[i]))
      img = ax.imshow(image)
      ax.imshow(map, cmap='gray', alpha=0.6, extent=img.get_extent(),
                clim=[0.0, np.max(map)])

    plt.tight_layout()
    

@Captioner.add_method
def run_and_show_attention(self, image, temperature=0.0):
    result_txt = self.simple_gen(image, temperature)
    str_tokens = result_txt.split()
    str_tokens.append('[END]')
    
    attention_maps = [layer.last_attention_scores for layer in self.decoder_layers]
    attention_maps = tf.concat(attention_maps, axis=0)
    attention_maps = einops.reduce(
      attention_maps,
      'batch heads sequence (height width) -> sequence height width',
      height=7, width=7,
      reduction='mean')
    
    plot_attention_maps(image/255, str_tokens, attention_maps)
    t = plt.suptitle(result_txt)
    t.set_y(1.05)

# %%
run_and_show_attention(model, load_image(str(pathlib.Path.cwd() / 'Model_Data/train_check/surf.jpg')))
