# %% [markdown]
# ## MOVIE GENRE CLASSIFICATION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Dataset Loading

# %%
df_train = pd.read_csv('dataset/train__data.txt',sep=':::', names=['Title', 'Genre', 'Description'], engine='python')
df_test = pd.read_csv('dataset/test__data.txt',sep=':::', names=['Title',  'Description'], engine='python')

# %%
df_train
# Out:
#                                               Title          Genre  \
# 1                     Oscar et la dame rose (2009)          drama
# 2                                     Cupid (1997)       thriller
# 3                 Young, Wild and Wonderful (1980)          adult
# 4                            The Secret Sin (1915)          drama
# 5                           The Unrecovered (2007)          drama
# ...                                             ...            ...
# 54210                              "Bonino" (1953)         comedy
# 54211                  Dead Girls Don't Cry (????)         horror
# 54212    Ronald Goedemondt: Ze bestaan echt (2008)    documentary
# 54213                     Make Your Own Bed (1944)         comedy
# 54214   Nature's Fury: Storm of the Century (2006)        history
#
#                                              Description
# 1       Listening in to a conversation between his do...
# 2       A brother and sister with a past incestuous r...
# 3       As the bus empties the students for their fie...
# 4       To help their unemployed father make ends mee...
# 5       The film's title refers not only to the un-re...
# ...                                                  ...
# 54210   This short-lived NBC live sitcom centered on ...
# 54211   The NEXT Generation of EXPLOITATION. The sist...
# 54212   Ze bestaan echt, is a stand-up comedy about g...
# 54213   Walter and Vivian live in the country and hav...
# 54214   On Labor Day Weekend, 1935, the most intense ...
#
# [54214 rows x 3 columns]

# %%
df_test
# Out:
#                                   Title  \
# 1                 Edgar's Lunch (1998)
# 2             La guerra de papá (1977)
# 3          Off the Beaten Track (2010)
# 4               Meu Amigo Hindu (2015)
# 5                    Er nu zhai (1955)
# ...                                 ...
# 54196   "Tales of Light & Dark" (2013)
# 54197      Der letzte Mohikaner (1965)
# 54198              Oliver Twink (2007)
# 54199                Slipstream (1973)
# 54200        Curitiba Zero Grau (2010)
#
#                                              Description
# 1       L.R. Brane loves his life - his car, his apar...
# 2       Spain, March 1964: Quico is a very naughty ch...
# 3       One year in the life of Albin and his family ...
# 4       His father has died, he hasn't spoken with hi...
# 5       Before he was known internationally as a mart...
# ...                                                  ...
# 54196   Covering multiple genres, Tales of Light & Da...
# 54197   As Alice and Cora Munro attempt to find their...
# 54198   A movie 169 years in the making. Oliver Twist...
# 54199   Popular, but mysterious rock D.J Mike Mallard...
# 54200   Curitiba is a city in movement, with rhythms ...
#
# [54200 rows x 2 columns]

# %% [markdown]
# Analysing datset

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54214 entries, 1 to 54214
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        54214 non-null  object
#  1   Genre        54214 non-null  object
#  2   Description  54214 non-null  object
# dtypes: object(3)
# memory usage: 1.7+ MB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54200 entries, 1 to 54200
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        54200 non-null  object
#  1   Description  54200 non-null  object
# dtypes: object(2)
# memory usage: 1.2+ MB

# %%
df_train.drop_duplicates(subset=['Description'], keep='first', inplace=True)

# %%
# after removing duplicate records
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54086 entries, 1 to 54214
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        54086 non-null  object
#  1   Genre        54086 non-null  object
#  2   Description  54086 non-null  object
# dtypes: object(3)
# memory usage: 1.7+ MB

# %% [markdown]
# Exploratory Data Analysis

# %%
df_train['Genre'].value_counts()
# Out:
#  drama           13572
#  documentary     13079
#  comedy           7429
#  short            5061
#  horror           2204
#  thriller         1590
#  action           1313
#  western          1032
#  reality-tv        882
#  adventure         775
#  family            774
#  music             719
#  romance           670
#  sci-fi            647
#  adult             589
#  crime             504
#  animation         497
#  sport             430
#  talk-show         387
#  fantasy           321
#  mystery           319
#  musical           277
#  biography         265
#  history           243
#  game-show         194
#  news              181
#  war               132
# Name: Genre, dtype: int64

# %%
genre_percentage = df_train['Genre'].value_counts(normalize=True) * 100
print(genre_percentage)
# Out:
#  drama           25.093370
#  documentary     24.181859
#  comedy          13.735532
#  short            9.357320
#  horror           4.074992
#  thriller         2.939763
#  action           2.427615
#  western          1.908072
#  reality-tv       1.630736
#  adventure        1.432903
#  family           1.431054
#  music            1.329364
#  romance          1.238768
#  sci-fi           1.196243
#  adult            1.089006
#  crime            0.931849
#  animation        0.918907
#  sport            0.795030
#  talk-show        0.715527
#  fantasy          0.593499
#  mystery          0.589801
#  musical          0.512147
#  biography        0.489960
#  history          0.449284
#  game-show        0.358688
#  news             0.334652
#  war              0.244056
# Name: Genre, dtype: float64

# %%
df_train['Genre'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# Text Processing

# %%
import spacy
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import re

# Load Spacy model
nlp = spacy.load("en_core_web_sm")

# Download NLTK stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# Initialize the stemmer
stemmer = PorterStemmer()
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>

# %%
# Define the preprocessing function
def preprocess(Description):
    # Convert text to lowercase
    Description = Description.lower()
    # Tokenize using spacy
    doc = nlp(Description)
    filtered_tokens = []
    for token in doc:
        # Remove special symbols
        token_text = re.sub(r'[^a-zA-Z0-9]', '', token.text)
        if not token_text:
            continue
        # Remove stopwords and punctuation
        if token_text in stop_words or token.is_punct:
            continue
        # Apply stemming
        stemmed_token = stemmer.stem(token_text)
        filtered_tokens.append(stemmed_token)
    
    return filtered_tokens

# %%
# Apply preprocessing to the Description column
df_train["text"] = df_train["Description"].apply(lambda text: preprocess(text))
df_train.head()
# Out:
#                                 Title       Genre  \
# 1       Oscar et la dame rose (2009)       drama
# 2                       Cupid (1997)    thriller
# 3   Young, Wild and Wonderful (1980)       adult
# 4              The Secret Sin (1915)       drama
# 5             The Unrecovered (2007)       drama
#
#                                          Description  \
# 1   Listening in to a conversation between his do...
# 2   A brother and sister with a past incestuous r...
# 3   As the bus empties the students for their fie...
# 4   To help their unemployed father make ends mee...
# 5   The film's title refers not only to the un-re...
#
#                                                 text
# 1  [listen, convers, doctor, parent, 10, year, ol...
# 2  [brother, sister, past, incestu, relationship,...
# 3  [bu, empti, student, field, trip, museum, natu...
# 4  [help, unemploy, father, make, end, meet, edit...
# 5  [film, titl, refer, un, recov, bodi, ground, z...

# %%
if isinstance(df_train['text'].iloc[0], list):
    df_train['text'] = df_train['text'].apply(lambda x: ' '.join(x))

# %%
df_train.head()
# Out:
#                                 Title       Genre  \
# 1       Oscar et la dame rose (2009)       drama
# 2                       Cupid (1997)    thriller
# 3   Young, Wild and Wonderful (1980)       adult
# 4              The Secret Sin (1915)       drama
# 5             The Unrecovered (2007)       drama
#
#                                          Description  \
# 1   Listening in to a conversation between his do...
# 2   A brother and sister with a past incestuous r...
# 3   As the bus empties the students for their fie...
# 4   To help their unemployed father make ends mee...
# 5   The film's title refers not only to the un-re...
#
#                                                 text
# 1  listen convers doctor parent 10 year old oscar...
# 2  brother sister past incestu relationship curre...
# 3  bu empti student field trip museum natur histo...
# 4  help unemploy father make end meet edith twin ...
# 5  film titl refer un recov bodi ground zero also...

# %%
df_test["text"] = df_test["Description"].apply(lambda text: preprocess(text))
df_test.head()
# Out:
#                            Title  \
# 1          Edgar's Lunch (1998)
# 2      La guerra de papá (1977)
# 3   Off the Beaten Track (2010)
# 4        Meu Amigo Hindu (2015)
# 5             Er nu zhai (1955)
#
#                                          Description  \
# 1   L.R. Brane loves his life - his car, his apar...
# 2   Spain, March 1964: Quico is a very naughty ch...
# 3   One year in the life of Albin and his family ...
# 4   His father has died, he hasn't spoken with hi...
# 5   Before he was known internationally as a mart...
#
#                                                 text
# 1  [lr, brane, love, life, car, apart, job, espec...
# 2  [spain, march, 1964, quico, naughti, child, th...
# 3  [one, year, life, albin, famili, shepherd, nor...
# 4  [father, die, nt, spoken, brother, 10, year, s...
# 5  [known, intern, martial, art, superstar, bruce...

# %%
if isinstance(df_test['text'].iloc[0], list):
    df_test['text'] = df_test['text'].apply(lambda x: ' '.join(x))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer()
x_train = tfidf.fit_transform(df_train['text'])
x_test=tfidf.transform(df_test['text'])
y_train= df_train['Genre']

# %% [markdown]
# Training and Evaluating the Model

# %%
# from sklearn.model_selection import train_test_split
from sklearn.metrics import  classification_report
from sklearn.metrics import accuracy_score,precision_score

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model_lr=LogisticRegression()
# train the model
model_lr.fit(x_train,y_train)
# Out:
# C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# training accuracy
y_pred_lr=model_lr.predict(x_train)
print(classification_report(y_test,y_pred_lr))
# Out:
# C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                precision    recall  f1-score   support
#
#       action        0.70      0.45      0.55      1313
#        adult        0.88      0.42      0.57       589
#    adventure        0.82      0.26      0.39       775
#    animation        0.80      0.19      0.31       497
#    biography        0.00      0.00      0.00       265
#       comedy        0.68      0.76      0.72      7429
#        crime        0.60      0.09      0.16       504
#  documentary        0.72      0.91      0.81     13079
#        drama        0.63      0.87      0.73     13572
#       family        0.76      0.17      0.27       774
#      fantasy        0.86      0.06      0.11       321
#    game-show        0.92      0.57      0.70       194
#      history        0.00      0.00      0.00       243
#       horror        0.79      0.73      0.76      2204
#        music        0.82      0.53      0.64       719
#      musical        0.83      0.07      0.13       277
#      mystery        0.74      0.04      0.08       319
#         news        0.75      0.07      0.12       181
#   reality-tv        0.76      0.32      0.45       882
#      romance        0.78      0.03      0.06       670
#       sci-fi        0.77      0.38      0.51       647
#        short        0.68      0.48      0.56      5061
#        sport        0.83      0.42      0.55       430
#    talk-show        0.76      0.28      0.41       387
#     thriller        0.69      0.27      0.39      1590
#          war        1.00      0.02      0.03       132
#      western        0.95      0.82      0.88      1032
#
#      accuracy                           0.69     54086
#     macro avg       0.72      0.34      0.40     54086
#  weighted avg       0.70      0.69      0.66     54086
# C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
print("accuracy score = ",accuracy_score(y_test,y_pred_lr)*100)
# Out:
# accuracy score =  69.32293014828237

# %% [markdown]
# RandomForest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
# define depth of our decision tree in random forest
model_rf=RandomForestClassifier(max_depth=10, random_state=50)
model_rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=10, random_state=50)

# %%
y_pred_rf=model_rf.predict(x_train)
print(classification_report(y_test,y_pred_rf))
# Out:
# C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                precision    recall  f1-score   support
#
#       action        0.00      0.00      0.00      1313
#        adult        0.00      0.00      0.00       589
#    adventure        0.00      0.00      0.00       775
#    animation        0.00      0.00      0.00       497
#    biography        0.00      0.00      0.00       265
#       comedy        1.00      0.00      0.00      7429
#        crime        0.00      0.00      0.00       504
#  documentary        0.54      0.86      0.66     13079
#        drama        0.36      0.88      0.51     13572
#       family        0.00      0.00      0.00       774
#      fantasy        0.00      0.00      0.00       321
#    game-show        0.00      0.00      0.00       194
#      history        0.00      0.00      0.00       243
#       horror        0.00      0.00      0.00      2204
#        music        0.00      0.00      0.00       719
#      musical        0.00      0.00      0.00       277
#      mystery        0.00      0.00      0.00       319
#         news        0.00      0.00      0.00       181
#   reality-tv        0.00      0.00      0.00       882
#      romance        0.00      0.00      0.00       670
#       sci-fi        0.00      0.00      0.00       647
#        short        0.00      0.00      0.00      5061
#        sport        0.00      0.00      0.00       430
#    talk-show        0.00      0.00      0.00       387
#     thriller        0.00      0.00      0.00      1590
#          war        0.00      0.00      0.00       132
#      western        0.00      0.00      0.00      1032
#
#      accuracy                           0.43     54086
#     macro avg       0.07      0.06      0.04     54086
#  weighted avg       0.36      0.43      0.29     54086
# C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
print("accuracy score = ",accuracy_score(y_test,y_pred_rf)*100)
# Out:
# accuracy score =  42.77631919535555

# %% [markdown]
# LinearSVC

# %%
from sklearn.svm import LinearSVC

# Train the SVM model
model_sv = LinearSVC()
model_sv.fit(x_train, y_train)
# Out:
# C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# LinearSVC()

# %%
# Predict and evaluate
y_pred = model_sv.predict(x_train)
print(classification_report(y_test, y_pred))
# Out:
#                precision    recall  f1-score   support
#
#       action        0.98      0.96      0.97      1313
#        adult        1.00      0.97      0.98       589
#    adventure        1.00      0.95      0.97       775
#    animation        0.99      0.95      0.97       497
#    biography        1.00      0.81      0.89       265
#       comedy        0.95      0.95      0.95      7429
#        crime        0.99      0.92      0.96       504
#  documentary        0.94      0.98      0.96     13079
#        drama        0.91      0.96      0.94     13572
#       family        0.99      0.91      0.95       774
#      fantasy        1.00      0.94      0.97       321
#    game-show        0.98      0.99      0.99       194
#      history        1.00      0.81      0.89       243
#       horror        0.96      0.98      0.97      2204
#        music        0.99      0.98      0.99       719
#      musical        1.00      0.92      0.96       277
#      mystery        1.00      0.93      0.96       319
#         news        0.99      0.90      0.94       181
#   reality-tv        0.99      0.92      0.95       882
#      romance        1.00      0.85      0.92       670
#       sci-fi        0.99      0.98      0.98       647
#        short        0.95      0.83      0.89      5061
#        sport        0.98      0.98      0.98       430
#    talk-show        0.99      0.97      0.98       387
#     thriller        0.98      0.86      0.92      1590
#          war        1.00      0.93      0.96       132
#      western        0.99      1.00      0.99      1032
#
#      accuracy                           0.95     54086
#     macro avg       0.98      0.93      0.96     54086
#  weighted avg       0.95      0.95      0.95     54086

# %%
print("accuracy score = ",accuracy_score(y_test,y_pred)*100)
# Out:
# accuracy score =  94.60303960359427

# %% [markdown]
# Multinomial Naive bayes

# %%
from sklearn.naive_bayes import MultinomialNB

model_mnb=MultinomialNB()
model_mnb.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
y_pred_mnb=model_mnb.predict(x_train)
print(classification_report(y_test,y_pred_mnb))
# Out:
# C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                precision    recall  f1-score   support
#
#       action        0.00      0.00      0.00      1313
#        adult        0.00      0.00      0.00       589
#    adventure        0.00      0.00      0.00       775
#    animation        0.00      0.00      0.00       497
#    biography        0.00      0.00      0.00       265
#       comedy        0.79      0.09      0.16      7429
#        crime        0.00      0.00      0.00       504
#  documentary        0.54      0.93      0.68     13079
#        drama        0.40      0.90      0.55     13572
#       family        0.00      0.00      0.00       774
#      fantasy        0.00      0.00      0.00       321
#    game-show        0.00      0.00      0.00       194
#      history        0.00      0.00      0.00       243
#       horror        1.00      0.00      0.00      2204
#        music        0.00      0.00      0.00       719
#      musical        0.00      0.00      0.00       277
#      mystery        0.00      0.00      0.00       319
#         news        0.00      0.00      0.00       181
#   reality-tv        0.00      0.00      0.00       882
#      romance        0.00      0.00      0.00       670
#       sci-fi        0.00      0.00      0.00       647
#        short        0.81      0.00      0.01      5061
#        sport        0.00      0.00      0.00       430
#    talk-show        0.00      0.00      0.00       387
#     thriller        0.00      0.00      0.00      1590
#          war        0.00      0.00      0.00       132
#      western        1.00      0.00      0.00      1032
#
#      accuracy                           0.46     54086
#     macro avg       0.17      0.07      0.05     54086
#  weighted avg       0.47      0.46      0.33     54086
# C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
print("accuracy score = ",accuracy_score(y_test,y_pred_mnb)*100)
# Out:
# accuracy score =  46.35580372000148

# %% [markdown]
# Prediction

# %%
# LinearSVC model for prediction
x_test_predictions=model_sv.predict(x_test)
df_test['Predicted_Genre']=x_test_predictions

# %%
df_test.to_csv("predicted_genre.csv",index=False)
df_test
# Out:
#                                   Title  \
# 1                 Edgar's Lunch (1998)
# 2             La guerra de papá (1977)
# 3          Off the Beaten Track (2010)
# 4               Meu Amigo Hindu (2015)
# 5                    Er nu zhai (1955)
# ...                                 ...
# 54196   "Tales of Light & Dark" (2013)
# 54197      Der letzte Mohikaner (1965)
# 54198              Oliver Twink (2007)
# 54199                Slipstream (1973)
# 54200        Curitiba Zero Grau (2010)
#
#                                              Description  \
# 1       L.R. Brane loves his life - his car, his apar...
# 2       Spain, March 1964: Quico is a very naughty ch...
# 3       One year in the life of Albin and his family ...
# 4       His father has died, he hasn't spoken with hi...
# 5       Before he was known internationally as a mart...
# ...                                                  ...
# 54196   Covering multiple genres, Tales of Light & Da...
# 54197   As Alice and Cora Munro attempt to find their...
# 54198   A movie 169 years in the making. Oliver Twist...
# 54199   Popular, but mysterious rock D.J Mike Mallard...
# 54200   Curitiba is a city in movement, with rhythms ...
#
#                                                     text Predicted_Genre
# 1      lr brane love life car apart job especi girlfr...         comedy
# 2      spain march 1964 quico naughti child three bel...          drama
# 3      one year life albin famili shepherd north tran...    documentary
# 4      father die nt spoken brother 10 year seriou ca...          drama
# 5      known intern martial art superstar bruce lee a...          drama
# ...                                                  ...             ...
# 54196  cover multipl genr tale light dark antholog we...          drama
# 54197  alic cora munro attempt find father british of...        western
# 54198  movi 169 year make oliv twist art dodger fagin...         comedy
# 54199  popular mysteri rock dj mike mallard askew bro...          drama
# 54200  curitiba citi movement rhythm differ pulsat gr...    documentary
#
# [54200 rows x 4 columns]
