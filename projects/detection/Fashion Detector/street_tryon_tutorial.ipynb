# %% [markdown]
# # Data Loading Tutorials for StreetTryOn Benchmark
# we provide code to load data for the tasks:
#
# In-the-wild tasks:
# - Street2Street (Top)
# - Street2Street (Dress)
#
# Studio tasks:
# - Shop2Model (VITON-HD task)
# - Model2Model
#
# Cross-domain tasks:
# - Shop2Street
# - Model2Street

# %%
import yaml
import torch

import matplotlib.pyplot as plt
# %matplotlib inline

from street_tryon_benchmark.dataset import GeneralTryOnDataset

# %%
def get_dataset(task):
    if task == 'shop2model':
        config_path = "street_tryon_benchmark/configs/shop2model.yaml"
    elif task == 'shop2street':
        config_path = "street_tryon_benchmark/configs/shop2street.yaml"
    elif task == 'model2model':
        config_path = "street_tryon_benchmark/configs/model2model.yaml"
    elif task == 'model2street':
        config_path = "street_tryon_benchmark/configs/model2street.yaml"
    elif task == 'street2street-top':
        config_path = "street_tryon_benchmark/configs/street2street_top.yaml"
    elif task == 'street2street-dress':
        config_path = "street_tryon_benchmark/configs/street2street_dress.yaml"
    else:
        raise NotImplementedError


    with open(config_path, "r") as f:
        data_config = yaml.safe_load(f)

    return GeneralTryOnDataset(".", config=data_config, split='test')

# %% [markdown]
# # Dataset for Street2Street (Top) Task

# %%
dataset = get_dataset('street2street-top')
curr = dataset[8]
pimg, pseg, piuv = curr['pimg'], curr['pseg'], curr['piuv']
gimg, gseg, giuv = curr['gimg'], curr['gseg'], curr['giuv']

plt.figure()
plt.imshow(torch.cat([pimg*0.5+0.5, piuv, pseg.expand_as(pimg)/20.0],-1).numpy().transpose(1,2,0))
plt.title("person image")
plt.figure()
plt.imshow(torch.cat([gimg*0.5+0.5, giuv, gseg.expand_as(gimg)/20.0],-1).numpy().transpose(1,2,0))
plt.title("garment image")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'garment image')

# %% [markdown]
# # Dataset for Street2Street (Dress) Task

# %%
dataset = get_dataset('street2street-dress')
curr = dataset[6]
pimg, pseg, piuv = curr['pimg'], curr['pseg'], curr['piuv']
gimg, gseg, giuv = curr['gimg'], curr['gseg'], curr['giuv']

plt.figure()
plt.imshow(torch.cat([pimg*0.5+0.5, piuv, pseg.expand_as(pimg)/20.0],-1).numpy().transpose(1,2,0))
plt.title("person image")
plt.figure()
plt.imshow(torch.cat([gimg*0.5+0.5, giuv, gseg.expand_as(gimg)/20.0],-1).numpy().transpose(1,2,0))
plt.title("garment image")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'garment image')

# %% [markdown]
# # Dataset for Shop2Model Task (Standard VITON-HD task)

# %%
dataset = get_dataset('shop2model')
curr = dataset[5]
pimg, pseg, piuv = curr['pimg'], curr['pseg'], curr['piuv']
gimg, gseg, giuv = curr['gimg'], curr['gseg'], curr['giuv']

plt.figure()
plt.imshow(torch.cat([pimg*0.5+0.5, piuv, pseg.expand_as(pimg)/20.0],-1).numpy().transpose(1,2,0))
plt.title("person image")
plt.figure()
plt.imshow(torch.cat([gimg*0.5+0.5, giuv, gseg.expand_as(gimg)/20.0],-1).numpy().transpose(1,2,0))
plt.title("garment image")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'garment image')

# %% [markdown]
# # Dataset for Model2Model Task

# %%
dataset = get_dataset('model2model')
curr = dataset[5]
pimg, pseg, piuv = curr['pimg'], curr['pseg'], curr['piuv']
gimg, gseg, giuv = curr['gimg'], curr['gseg'], curr['giuv']

plt.figure()
plt.imshow(torch.cat([pimg*0.5+0.5, piuv, pseg.expand_as(pimg)/20.0],-1).numpy().transpose(1,2,0))
plt.title("person image")
plt.figure()
plt.imshow(torch.cat([gimg*0.5+0.5, giuv, gseg.expand_as(gimg)/20.0],-1).numpy().transpose(1,2,0))
plt.title("garment image")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'garment image')

# %% [markdown]
# # Cross-domain - Dataset for Model2Street Task

# %%
dataset = get_dataset('model2street')
curr = dataset[54]
pimg, pseg, piuv = curr['pimg'], curr['pseg'], curr['piuv']
gimg, gseg, giuv = curr['gimg'], curr['gseg'], curr['giuv']

plt.figure()
plt.imshow(torch.cat([pimg*0.5+0.5, piuv, pseg.expand_as(pimg)/20.0],-1).numpy().transpose(1,2,0))
plt.title("person image")
plt.figure()
plt.imshow(torch.cat([gimg*0.5+0.5, giuv, gseg.expand_as(gimg)/20.0],-1).numpy().transpose(1,2,0))
plt.title("garment image")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'garment image')

# %% [markdown]
# # Cross-domain - Dataset for Shop2Street Task

# %%
dataset = get_dataset('shop2street')
curr = dataset[54]
pimg, pseg, piuv = curr['pimg'], curr['pseg'], curr['piuv']
gimg, gseg, giuv = curr['gimg'], curr['gseg'], curr['giuv']

plt.figure()
plt.imshow(torch.cat([pimg*0.5+0.5, piuv, pseg.expand_as(pimg)/20.0],-1).numpy().transpose(1,2,0))
plt.title("person image")
plt.figure()
plt.imshow(torch.cat([gimg*0.5+0.5, giuv, gseg.expand_as(gimg)/20.0],-1).numpy().transpose(1,2,0))
plt.title("garment image")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'garment image')
