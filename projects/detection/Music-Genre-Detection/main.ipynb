# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import librosa.display 
from sklearn import preprocessing 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report
import pickle as pkl
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
import catboost as cb 
from xgboost import XGBClassifier
import tensorflow.keras as keras 
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import *

# %% [markdown]
# ### Basic Inspection

# %%
df = pd.read_csv('archive/Data/dataset.csv') 
df.head()
# Out:
#           filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0  blues.00000.wav  661794          0.350088         0.088757  0.130228
# 1  blues.00001.wav  661794          0.340914         0.094980  0.095948
# 2  blues.00002.wav  661794          0.363637         0.085275  0.175570
# 3  blues.00003.wav  661794          0.404785         0.093999  0.141093
# 4  blues.00004.wav  661794          0.308526         0.087841  0.091529
#
#     rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  0.002827             1784.165850          129774.064525
# 1  0.002373             1530.176679          375850.073649
# 2  0.002746             1552.811865          156467.643368
# 3  0.006346             1070.106615          184355.942417
# 4  0.002303             1835.004266          343399.939274
#
#    spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc16_var  \
# 0              2002.449060            85882.761315  ...   52.420910
# 1              2039.036516           213843.755497  ...   55.356403
# 2              1747.702312            76254.192257  ...   40.598766
# 3              1596.412872           166441.494769  ...   44.427753
# 4              1748.172116            88445.209036  ...   86.099236
#
#    mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  mfcc19_var  \
# 0    -1.690215   36.524071    -0.408979   41.597103    -2.303523   55.062923
# 1    -0.731125   60.314529     0.295073   48.120598    -0.283518   51.106190
# 2    -7.729093   47.639427    -1.816407   52.382141    -3.439720   46.639660
# 3    -3.319597   50.206673     0.636965   37.319130    -0.619121   37.259739
# 4    -5.454034   75.269707    -0.916874   53.613918    -4.404827   62.910812
#
#    mfcc20_mean  mfcc20_var  label
# 0     1.221291   46.936035  blues
# 1     0.531217   45.786282  blues
# 2    -2.231258   30.573025  blues
# 3    -3.407448   31.949339  blues
# 4   -11.703234   55.195160  blues
#
# [5 rows x 60 columns]

# %%
df.shape
# Out:
# (1000, 60)

# %%
df['label'].value_counts()
# Out:
# blues        100
# classical    100
# country      100
# disco        100
# hiphop       100
# jazz         100
# metal        100
# pop          100
# reggae       100
# rock         100
# Name: label, dtype: int64

# %% [markdown]
# #### Wavelength of various music genres

# %%
path = 'archive/Data/genres_original/blues/blues.00000.wav'
plt.figure(figsize=(14, 5)) 
x, sr = librosa.load(path) 
librosa.display.waveshow(x, sr=sr) 
print("Blue")
# Out:
# Blue

# %%
path = 'archive/Data/genres_original/reggae/reggae.00000.wav'
plt.figure(figsize=(14, 5)) 
x, sr = librosa.load(path) 
librosa.display.waveshow(x, sr=sr,color='green')
print("Reggae")
# Out:
# Reggae

# %%
path = 'archive/Data/genres_original/rock/rock.00000.wav'
plt.figure(figsize=(14, 5)) 
x, sr = librosa.load(path) 
librosa.display.waveshow(x, sr=sr,color='black')
print("Rock")
# Out:
# Rock

# %%
spike = [col for col in df.columns if 'mean' in col] 

f, ax = plt.subplots(figsize=(16, 11)); 
  

sns.heatmap(df[spike].corr(), cmap='YlGn') 
  
plt.title('Heatmap for mean variables', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Heatmap for mean variables')

# %%
label_encoder = preprocessing.LabelEncoder() 
df['label'] = label_encoder.fit_transform(df['label'])

# %%
X = df.drop(['label','filename'],axis=1) 
y = df['label']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-96bb4d0d1176> in <module>
# ----> 1 X = df.drop(['label','filename'],axis=1)
#       2 y = df['label']
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### Model Training

# %%
cols = X.columns 
minmax = preprocessing.MinMaxScaler() 
np_scaled = minmax.fit_transform(X) 
  
# new data frame with the new scaled data.  
X = pd.DataFrame(np_scaled, columns = cols)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=111) 
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((700, 58), (300, 58), (700,), (300,))

# %% [markdown]
# - Logistic Regression
# - Decision Tree Classifier
# - Random Forest Classifier
# - KNN

# %%
lr=LogisticRegression(C = 0.1, random_state = 42, solver = 'liblinear')
dt=DecisionTreeClassifier()
knn = KNeighborsClassifier(n_neighbors=3)

# %%
for a,b in zip([lr,dt,knn],["Logistic Regression","Decision Tree","KNN"]):
    a.fit(x_train,y_train)
    prediction=a.predict(x_train)
    y_pred=a.predict(x_test)
    score1=accuracy_score(y_train,prediction)
    score=accuracy_score(y_test,y_pred)
    msg1="[%s] training data accuracy is : %f" % (b,score1)
    msg2="[%s] test data accuracy is : %f" % (b,score)
    print(msg1)
    print(msg2)
# Out:
# [Logistic Regression] training data accuracy is : 0.538571
# [Logistic Regression] test data accuracy is : 0.523333
# [Decision Tree] training data accuracy is : 0.998571
# [Decision Tree] test data accuracy is : 0.620000
# [KNN] training data accuracy is : 0.832857
# [KNN] test data accuracy is : 0.706667

# %%
model_scores={'Logistic Regression':lr.score(x_test,y_test),
             'KNN classifier':knn.score(x_test,y_test),
              'Decision tree':dt.score(x_test,y_test)
             }
model_scores
# Out:
# {'Logistic Regression': 0.5233333333333333,
#  'KNN classifier': 0.7066666666666667,
#  'Decision tree': 0.62}

# %%
model_compare=pd.DataFrame(model_scores,index=['accuracy'])
model_compare
# Out:
#           Logistic Regression  KNN classifier  Decision tree
# accuracy             0.523333        0.706667           0.62

# %%
model_compare.T.plot(kind='bar') # (T is here for transpose)
# Out:
# <AxesSubplot:>

# %% [markdown]
# - KNN is giving the best accuracy out of these but is still not that good

# %%
  
rf = RandomForestClassifier(n_estimators=1000, max_depth=10, random_state=0) 
cbc = cb.CatBoostClassifier(verbose=0, eval_metric='Accuracy', loss_function='MultiClass') 
xgb = XGBClassifier(n_estimators=1000, learning_rate=0.05) 
  
for clf in (rf, cbc, xgb): 
    clf.fit(x_train, y_train) 
    preds = clf.predict(x_test) 
    print(clf.__class__.__name__,accuracy_score(y_test, preds))
# Out:
# RandomForestClassifier 0.78
# CatBoostClassifier 0.8333333333333334
# XGBClassifier 0.7733333333333333

# %%
model_scores={'Random Forest':rf.score(x_test,y_test),
             'Cat Boost Classifier':cbc.score(x_test,y_test),
              'XGBC Classifier':xgb.score(x_test,y_test)
             }
model_compare=pd.DataFrame(model_scores,index=['accuracy'])
print(model_compare)
model_compare.T.plot(kind='bar') # (T is here for transpose)
# Out:
#           Random Forest  Cat Boost Classifier  XGBC Classifier
# accuracy           0.78              0.833333         0.773333
# <AxesSubplot:>

# %% [markdown]
# - Cat Boost Classifier gives the best results

# %% [markdown]
# - Neural Network

# %%
model = Sequential() 
  
model.add(Flatten(input_shape=(58,))) 
model.add(Dense(256, activation='relu')) 
model.add(BatchNormalization()) 
model.add(Dense(128, activation='relu')) 
model.add(Dropout(0.3)) 
model.add(Dense(10, activation='softmax')) 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 58)                0
#
#  dense (Dense)               (None, 256)               15104
#
#  batch_normalization (BatchN  (None, 256)              1024
#  ormalization)
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_2 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 50,314
# Trainable params: 49,802
# Non-trainable params: 512
# _________________________________________________________________

# %%
adam = keras.optimizers.Adam(lr=1e-4) 
model.compile(optimizer=adam, 
             loss="sparse_categorical_crossentropy", 
             metrics=["accuracy"]) 
  
hist = model.fit(x_train, y_train, 
                 validation_data = (x_test,y_test), 
                 epochs = 100, 
                 batch_size = 32)
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/100
# 22/22 [==============================] - 1s 10ms/step - loss: 1.8715 - accuracy: 0.3629 - val_loss: 2.1749 - val_accuracy: 0.2300
# Epoch 2/100
# 22/22 [==============================] - 0s 4ms/step - loss: 1.2869 - accuracy: 0.5400 - val_loss: 2.1184 - val_accuracy: 0.2200
# Epoch 3/100
# 22/22 [==============================] - 0s 3ms/step - loss: 1.0499 - accuracy: 0.6200 - val_loss: 2.0368 - val_accuracy: 0.3600
# Epoch 4/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.9141 - accuracy: 0.6857 - val_loss: 1.9680 - val_accuracy: 0.3400
# Epoch 5/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.8218 - accuracy: 0.7271 - val_loss: 1.8772 - val_accuracy: 0.5167
# Epoch 6/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.7158 - accuracy: 0.7686 - val_loss: 1.7537 - val_accuracy: 0.6433
# Epoch 7/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6488 - accuracy: 0.7857 - val_loss: 1.7052 - val_accuracy: 0.5800
# Epoch 8/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6625 - accuracy: 0.7714 - val_loss: 1.5925 - val_accuracy: 0.6467
# Epoch 9/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6055 - accuracy: 0.7986 - val_loss: 1.4898 - val_accuracy: 0.7367
# Epoch 10/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.5576 - accuracy: 0.8100 - val_loss: 1.4270 - val_accuracy: 0.6967
# Epoch 11/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.5528 - accuracy: 0.8100 - val_loss: 1.3546 - val_accuracy: 0.7467
# Epoch 12/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.5012 - accuracy: 0.8329 - val_loss: 1.2434 - val_accuracy: 0.7333
# Epoch 13/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.4491 - accuracy: 0.8614 - val_loss: 1.1463 - val_accuracy: 0.7433
# Epoch 14/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.4454 - accuracy: 0.8557 - val_loss: 1.0870 - val_accuracy: 0.7400
# Epoch 15/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.3993 - accuracy: 0.8714 - val_loss: 1.0420 - val_accuracy: 0.7733
# Epoch 16/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3982 - accuracy: 0.8586 - val_loss: 0.9490 - val_accuracy: 0.7900
# Epoch 17/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.3745 - accuracy: 0.8729 - val_loss: 0.9281 - val_accuracy: 0.7633
# Epoch 18/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.3722 - accuracy: 0.8914 - val_loss: 0.8634 - val_accuracy: 0.7700
# Epoch 19/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.3590 - accuracy: 0.8757 - val_loss: 0.8134 - val_accuracy: 0.7800
# Epoch 20/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3253 - accuracy: 0.8886 - val_loss: 0.7935 - val_accuracy: 0.7633
# Epoch 21/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.3073 - accuracy: 0.9043 - val_loss: 0.7416 - val_accuracy: 0.7767
# Epoch 22/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.3026 - accuracy: 0.9071 - val_loss: 0.7713 - val_accuracy: 0.7733
# Epoch 23/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2984 - accuracy: 0.9057 - val_loss: 0.7383 - val_accuracy: 0.7633
# Epoch 24/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2780 - accuracy: 0.9000 - val_loss: 0.7328 - val_accuracy: 0.7633
# Epoch 25/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2500 - accuracy: 0.9171 - val_loss: 0.6863 - val_accuracy: 0.7867
# Epoch 26/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2302 - accuracy: 0.9286 - val_loss: 0.7581 - val_accuracy: 0.7700
# Epoch 27/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2851 - accuracy: 0.8971 - val_loss: 0.7740 - val_accuracy: 0.7400
# Epoch 28/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2682 - accuracy: 0.9243 - val_loss: 0.7677 - val_accuracy: 0.7767
# Epoch 29/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2235 - accuracy: 0.9371 - val_loss: 0.7684 - val_accuracy: 0.7567
# Epoch 30/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2347 - accuracy: 0.9243 - val_loss: 0.8157 - val_accuracy: 0.7767
# Epoch 31/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2143 - accuracy: 0.9357 - val_loss: 0.8139 - val_accuracy: 0.7633
# Epoch 32/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2228 - accuracy: 0.9243 - val_loss: 0.8417 - val_accuracy: 0.7533
# Epoch 33/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1917 - accuracy: 0.9343 - val_loss: 0.8153 - val_accuracy: 0.7833
# Epoch 34/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1630 - accuracy: 0.9500 - val_loss: 0.8262 - val_accuracy: 0.7600
# Epoch 35/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1662 - accuracy: 0.9486 - val_loss: 0.7933 - val_accuracy: 0.7867
# Epoch 36/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1518 - accuracy: 0.9529 - val_loss: 0.8035 - val_accuracy: 0.7733
# Epoch 37/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1642 - accuracy: 0.9529 - val_loss: 0.8425 - val_accuracy: 0.7833
# Epoch 38/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1445 - accuracy: 0.9571 - val_loss: 0.8426 - val_accuracy: 0.7700
# Epoch 39/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1357 - accuracy: 0.9700 - val_loss: 0.9062 - val_accuracy: 0.7800
# Epoch 40/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1559 - accuracy: 0.9486 - val_loss: 0.8665 - val_accuracy: 0.7567
# Epoch 41/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1383 - accuracy: 0.9671 - val_loss: 0.8667 - val_accuracy: 0.7667
# Epoch 42/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1421 - accuracy: 0.9600 - val_loss: 0.9131 - val_accuracy: 0.7700
# Epoch 43/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.1300 - accuracy: 0.9657 - val_loss: 0.9878 - val_accuracy: 0.7233
# Epoch 44/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1466 - accuracy: 0.9486 - val_loss: 0.8539 - val_accuracy: 0.7733
# Epoch 45/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1748 - accuracy: 0.9443 - val_loss: 0.8871 - val_accuracy: 0.7667
# Epoch 46/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1740 - accuracy: 0.9443 - val_loss: 0.9845 - val_accuracy: 0.6967
# Epoch 47/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1664 - accuracy: 0.9457 - val_loss: 0.9997 - val_accuracy: 0.7433
# Epoch 48/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2003 - accuracy: 0.9257 - val_loss: 0.9346 - val_accuracy: 0.7400
# Epoch 49/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1340 - accuracy: 0.9586 - val_loss: 0.8827 - val_accuracy: 0.7767
# Epoch 50/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1302 - accuracy: 0.9657 - val_loss: 0.8912 - val_accuracy: 0.7800
# Epoch 51/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1327 - accuracy: 0.9543 - val_loss: 1.1564 - val_accuracy: 0.7167
# Epoch 52/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1224 - accuracy: 0.9671 - val_loss: 0.9441 - val_accuracy: 0.7667
# Epoch 53/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1072 - accuracy: 0.9686 - val_loss: 1.0462 - val_accuracy: 0.7367
# Epoch 54/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1257 - accuracy: 0.9643 - val_loss: 0.9726 - val_accuracy: 0.7733
# Epoch 55/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1109 - accuracy: 0.9700 - val_loss: 0.9440 - val_accuracy: 0.7700
# Epoch 56/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0839 - accuracy: 0.9800 - val_loss: 1.0257 - val_accuracy: 0.7500
# Epoch 57/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1037 - accuracy: 0.9643 - val_loss: 1.0421 - val_accuracy: 0.7700
# Epoch 58/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1385 - accuracy: 0.9543 - val_loss: 1.1698 - val_accuracy: 0.7267
# Epoch 59/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1428 - accuracy: 0.9571 - val_loss: 1.1057 - val_accuracy: 0.7467
# Epoch 60/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1251 - accuracy: 0.9571 - val_loss: 1.0733 - val_accuracy: 0.7467
# Epoch 61/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0827 - accuracy: 0.9786 - val_loss: 0.9696 - val_accuracy: 0.7667
# Epoch 62/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0922 - accuracy: 0.9700 - val_loss: 1.0237 - val_accuracy: 0.7533
# Epoch 63/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0867 - accuracy: 0.9743 - val_loss: 1.1542 - val_accuracy: 0.7333
# Epoch 64/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0879 - accuracy: 0.9757 - val_loss: 1.0092 - val_accuracy: 0.7867
# Epoch 65/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1049 - accuracy: 0.9657 - val_loss: 1.0092 - val_accuracy: 0.7700
# Epoch 66/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0867 - accuracy: 0.9743 - val_loss: 1.0355 - val_accuracy: 0.7633
# Epoch 67/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1017 - accuracy: 0.9686 - val_loss: 1.0045 - val_accuracy: 0.7633
# Epoch 68/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0980 - accuracy: 0.9729 - val_loss: 1.1774 - val_accuracy: 0.7367
# Epoch 69/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0925 - accuracy: 0.9714 - val_loss: 0.9756 - val_accuracy: 0.7733
# Epoch 70/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0660 - accuracy: 0.9814 - val_loss: 1.1072 - val_accuracy: 0.7567
# Epoch 71/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1114 - accuracy: 0.9629 - val_loss: 1.0122 - val_accuracy: 0.7767
# Epoch 72/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0966 - accuracy: 0.9743 - val_loss: 1.2847 - val_accuracy: 0.7400
# Epoch 73/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0879 - accuracy: 0.9786 - val_loss: 1.0501 - val_accuracy: 0.7600
# Epoch 74/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1010 - accuracy: 0.9700 - val_loss: 1.0723 - val_accuracy: 0.7567
# Epoch 75/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0782 - accuracy: 0.9743 - val_loss: 1.1044 - val_accuracy: 0.7533
# Epoch 76/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0900 - accuracy: 0.9743 - val_loss: 1.1279 - val_accuracy: 0.7533
# Epoch 77/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1052 - accuracy: 0.9629 - val_loss: 1.1111 - val_accuracy: 0.7333
# Epoch 78/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0934 - accuracy: 0.9714 - val_loss: 1.2342 - val_accuracy: 0.7200
# Epoch 79/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0955 - accuracy: 0.9714 - val_loss: 1.3085 - val_accuracy: 0.7067
# Epoch 80/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0938 - accuracy: 0.9714 - val_loss: 1.1868 - val_accuracy: 0.7667
# Epoch 81/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0894 - accuracy: 0.9757 - val_loss: 1.1225 - val_accuracy: 0.7467
# Epoch 82/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0827 - accuracy: 0.9743 - val_loss: 1.1583 - val_accuracy: 0.7500
# Epoch 83/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0731 - accuracy: 0.9800 - val_loss: 1.2260 - val_accuracy: 0.7367
# Epoch 84/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0991 - accuracy: 0.9643 - val_loss: 1.4553 - val_accuracy: 0.7000
# Epoch 85/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0935 - accuracy: 0.9671 - val_loss: 1.3062 - val_accuracy: 0.7267
# Epoch 86/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0766 - accuracy: 0.9814 - val_loss: 1.1469 - val_accuracy: 0.7733
# Epoch 87/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0964 - accuracy: 0.9643 - val_loss: 1.0376 - val_accuracy: 0.7533
# Epoch 88/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0815 - accuracy: 0.9700 - val_loss: 1.5214 - val_accuracy: 0.6600
# Epoch 89/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0682 - accuracy: 0.9900 - val_loss: 1.2731 - val_accuracy: 0.7400
# Epoch 90/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0756 - accuracy: 0.9771 - val_loss: 1.0490 - val_accuracy: 0.7700
# Epoch 91/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0809 - accuracy: 0.9729 - val_loss: 1.2109 - val_accuracy: 0.7400
# Epoch 92/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0714 - accuracy: 0.9800 - val_loss: 1.1146 - val_accuracy: 0.7800
# Epoch 93/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0847 - accuracy: 0.9714 - val_loss: 1.1461 - val_accuracy: 0.7433
# Epoch 94/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0751 - accuracy: 0.9757 - val_loss: 1.1648 - val_accuracy: 0.7567
# Epoch 95/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0537 - accuracy: 0.9886 - val_loss: 1.1865 - val_accuracy: 0.7500
# Epoch 96/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0674 - accuracy: 0.9786 - val_loss: 1.2342 - val_accuracy: 0.7367
# Epoch 97/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0592 - accuracy: 0.9843 - val_loss: 1.2892 - val_accuracy: 0.7233
# Epoch 98/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0597 - accuracy: 0.9829 - val_loss: 1.3270 - val_accuracy: 0.7433
# Epoch 99/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0521 - accuracy: 0.9857 - val_loss: 1.4556 - val_accuracy: 0.7133
# Epoch 100/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0692 - accuracy: 0.9771 - val_loss: 1.2000 - val_accuracy: 0.7500

# %%
test_error, test_accuracy = model.evaluate(x_test, y_test, verbose=1) 
print(f"Test accuracy: {test_accuracy}")
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 1.2000 - accuracy: 0.7500
# Test accuracy: 0.75

# %%
fig, axs = plt.subplots(2,figsize=(10,10)) 
  
# accuracy  
axs[0].plot(hist.history["accuracy"], label="train") 
axs[0].plot(hist.history["val_accuracy"], label="test")     
axs[0].set_ylabel("Accuracy") 
axs[0].legend() 
axs[0].set_title("Accuracy") 
      
# Error  
axs[1].plot(hist.history["loss"], label="train") 
axs[1].plot(hist.history["val_loss"], label="test")     
axs[1].set_ylabel("Error") 
axs[1].legend() 
axs[1].set_title("Error") 
      
plt.show()

# %% [markdown]
# - since cat boost classfier gave us the best accuracy we are going to test using that model

# %%
save_model = pkl.dumps(cbc)
cbcr_pkl = pkl.loads(save_model)


predictions =cbc.predict(x_test)
true_labels = y_test 

accuracy = accuracy_score(true_labels, predictions)
print(f"Accuracy: {accuracy * 100:.2f}%")


report = classification_report(true_labels, predictions)
print("Classification Report:\n", report)
# Out:
# Accuracy: 83.33%
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80        30
#            1       0.91      0.91      0.91        32
#            2       0.85      0.81      0.83        27
#            3       0.83      0.83      0.83        30
#            4       0.83      0.83      0.83        24
#            5       0.77      0.79      0.78        29
#            6       0.89      0.86      0.88        29
#            7       0.97      0.94      0.96        36
#            8       0.77      0.84      0.81        32
#            9       0.70      0.68      0.69        31
#
#     accuracy                           0.83       300
#    macro avg       0.83      0.83      0.83       300
# weighted avg       0.83      0.83      0.83       300

# %% [markdown]
# #### Prediction

# %%
save_model=pkl.dumps(cbc)
cbc_pkl=pkl.loads(save_model)
cbc_pkl.predict(x_test)
# Out:
# array([[1],
#        [1],
#        [2],
#        [0],
#        [0],
#        [5],
#        [8],
#        [8],
#        [1],
#        [9],
#        [3],
#        [7],
#        [7],
#        [9],
#        [8],
#        [0],
#        [0],
#        [6],
#        [6],
#        [1],
#        [4],
#        [6],
#        [3],
#        [3],
#        [8],
#        [7],
#        [8],
#        [7],
#        [6],
#        [0],
#        [7],
#        [8],
#        [8],
#        [4],
#        [7],
#        [9],
#        [3],
#        [9],
#        [6],
#        [4],
#        [0],
#        [6],
#        [4],
#        [0],
#        [8],
#        [7],
#        [0],
#        [4],
#        [8],
#        [5],
#        [3],
#        [4],
#        [7],
#        [9],
#        [3],
#        [6],
#        [4],
#        [8],
#        [9],
#        [7],
#        [9],
#        [9],
#        [1],
#        [8],
#        [0],
#        [5],
#        [9],
#        [8],
#        [7],
#        [5],
#        [8],
#        [0],
#        [3],
#        [1],
#        [7],
#        [6],
#        [6],
#        [8],
#        [3],
#        [3],
#        [9],
#        [7],
#        [3],
#        [8],
#        [5],
#        [2],
#        [0],
#        [2],
#        [9],
#        [4],
#        [5],
#        [1],
#        [1],
#        [8],
#        [2],
#        [1],
#        [1],
#        [6],
#        [2],
#        [0],
#        [3],
#        [0],
#        [5],
#        [8],
#        [2],
#        [7],
#        [3],
#        [0],
#        [0],
#        [8],
#        [5],
#        [7],
#        [5],
#        [8],
#        [9],
#        [5],
#        [1],
#        [2],
#        [7],
#        [8],
#        [9],
#        [7],
#        [4],
#        [7],
#        [9],
#        [3],
#        [8],
#        [9],
#        [2],
#        [1],
#        [6],
#        [4],
#        [1],
#        [8],
#        [1],
#        [5],
#        [7],
#        [9],
#        [6],
#        [7],
#        [8],
#        [4],
#        [0],
#        [7],
#        [1],
#        [4],
#        [6],
#        [9],
#        [0],
#        [5],
#        [6],
#        [6],
#        [0],
#        [5],
#        [5],
#        [4],
#        [2],
#        [5],
#        [4],
#        [5],
#        [9],
#        [9],
#        [2],
#        [7],
#        [3],
#        [5],
#        [1],
#        [6],
#        [0],
#        [1],
#        [7],
#        [2],
#        [3],
#        [5],
#        [9],
#        [3],
#        [2],
#        [1],
#        [1],
#        [4],
#        [1],
#        [2],
#        [6],
#        [3],
#        [7],
#        [7],
#        [8],
#        [6],
#        [6],
#        [4],
#        [5],
#        [8],
#        [1],
#        [3],
#        [8],
#        [8],
#        [4],
#        [8],
#        [2],
#        [6],
#        [5],
#        [1],
#        [0],
#        [9],
#        [9],
#        [3],
#        [7],
#        [4],
#        [9],
#        [5],
#        [9],
#        [7],
#        [0],
#        [4],
#        [4],
#        [9],
#        [7],
#        [1],
#        [5],
#        [5],
#        [1],
#        [1],
#        [6],
#        [6],
#        [0],
#        [1],
#        [5],
#        [6],
#        [4],
#        [3],
#        [6],
#        [8],
#        [2],
#        [2],
#        [0],
#        [5],
#        [4],
#        [7],
#        [2],
#        [2],
#        [3],
#        [9],
#        [9],
#        [2],
#        [0],
#        [1],
#        [6],
#        [2],
#        [4],
#        [7],
#        [7],
#        [9],
#        [3],
#        [3],
#        [2],
#        [8],
#        [5],
#        [1],
#        [3],
#        [8],
#        [0],
#        [2],
#        [9],
#        [5],
#        [0],
#        [6],
#        [1],
#        [3],
#        [4],
#        [2],
#        [6],
#        [7],
#        [8],
#        [8],
#        [7],
#        [0],
#        [7],
#        [3],
#        [9],
#        [0],
#        [5],
#        [8],
#        [7],
#        [3],
#        [2],
#        [2],
#        [7],
#        [1],
#        [6],
#        [2],
#        [1],
#        [0],
#        [0],
#        [5],
#        [5],
#        [3],
#        [8],
#        [3],
#        [1],
#        [3]])
