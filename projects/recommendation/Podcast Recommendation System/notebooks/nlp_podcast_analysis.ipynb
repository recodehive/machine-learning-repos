# %%
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import unidecode
import re

# %% [markdown]
# # Load Podcast Data

# %%
podcasts_df = pd.read_pickle('../pickle_files/english_podcasts_detailed_cleaned.pkl')

# %%
podcasts_df
# Out:
#                                                   title  \
# 0     History Hyenas with Chris Distefano and Yannis...
# 1                                       Curiosity Daily
# 2                                               Spirits
# 3                                   The Soundtrack Show
# 4                                       Writing Excuses
# 5                         Steve McNair: Fall of a Titan
# 6                                      The Science Hour
# 7                    The 5 AM Miracle with Jeff Sanders
# 8                      Race Chaser with Alaska & Willam
# 9                                   Amy Should Be Forty
# 10                      Bogleheads On Investing Podcast
# 11                 Against the Rules with Michael Lewis
# 12                                                STAT!
# 13                                            Mythology
# 14                                            No Jumper
# 15                                 Happier in Hollywood
# 16            ABA Journal Podcasts - Legal Talk Network
# 17                                      Nobilis Erotica
# 18                       Beach Too Sandy, Water Too Wet
# 19                             Gardeners' Question Time
# 20           Biology 3020 -- Pathophysiology with Doc C
# 21              Dan Carlin's Hardcore History: Addendum
# 22         CBS Sports Eye On College Basketball Podcast
# 23                                    Eleanor Amplified
# 24                                         The PodGOATs
# 25                                             Moonrise
# 26                  The Sustainable Minimalists Podcast
# 27                                   Phil in the Blanks
# 28                                  Classical Classroom
# 29                             PODRUNNER: Workout Music
# ...                                                 ...
# 4273                                            Catlick
# 4274                      Elevation with Steven Furtick
# 4275                                     Edit Your Life
# 4276                                                PTI
# 4277  The Great Composers Podcast - a classical musi...
# 4278                                   The BEMA Podcast
# 4279                           The Leviathan Chronicles
# 4280                          MrCreepyPasta's Storytime
# 4281                           The Obesity Code Podcast
# 4282                             Pregnancy Confidential
# 4283                                The Lawfare Podcast
# 4284  Slate Presents: The Queen | The Forgotten Life...
# 4285                                      Snap Judgment
# 4286                                       Sole Podcast
# 4287                                     All the Books!
# 4288    The Poker Coaching Podcast with Jonathan Little
# 4289                 Craig Groeschel Leadership Podcast
# 4290                 The Majority Report with Sam Seder
# 4291                              25 Songs of Christmas
# 4292                               Poetry Off the Shelf
# 4293                          Anna Faris Is Unqualified
# 4294                                     The Album Club
# 4295                                  Jimmy Kimmel Live
# 4296                                         #ITSNEEDED
# 4297                                   Among The Lilies
# 4298                                     Dark Histories
# 4299                                          Red Scare
# 4300                                 The Amelia Project
# 4301                           L.A. Not So Confidential
# 4302                                        Food 4 Thot
#
#                                                producer  \
# 0                                      RiotCast Network
# 1                                          Westwood One
# 2                                             Multitude
# 3                                           iHeartRadio
# 4     Brandon Sanderson, Mary Robinette Kowal, Dan W...
# 5                                    Sports Illustrated
# 6                                                   BBC
# 7                                          Jeff Sanders
# 8                                           Forever Dog
# 9                                         VAULT Studios
# 10                                           bogleheads
# 11                                   Pushkin Industries
# 12    Medical True Crime, Bizarre, Mysterious and Un...
# 13                                              Parcast
# 14                                            No Jumper
# 15                                              Panoply
# 16                                   Legal Talk Network
# 17                                         Nobilis Reed
# 18                          Alex and Christine Schiefer
# 19                                                  BBC
# 20                                   Dr. Gerald Cizadlo
# 21                                        Wizzard Media
# 22                                           CBS Sports
# 23                                                 WHYY
# 24                                       Comworld Media
# 25                                  The Washington Post
# 26                                   Stephanie Seferian
# 27                                             Dr. Phil
# 28                                           Dacia Clay
# 29                                        Wizzard Media
# ...                                                 ...
# 4273                                        B.T. Harman
# 4274                                   Elevation Church
# 4275                      Christine Koh + Asha Dornfest
# 4276                                               ESPN
# 4277                                    Kevin Nordstrom
# 4278                                  BEMA Discipleship
# 4279                                   Christof Laputka
# 4280                                      MrCreepyPasta
# 4281                                      Carl Franklin
# 4282                                  Parents / Panoply
# 4283                              The Lawfare Institute
# 4284                                     Slate Magazine
# 4285                                               WNYC
# 4286                                   Through the Word
# 4287                                          Book Riot
# 4288                                    Jonathan Little
# 4289                                        Life.Church
# 4290                                          Sam Seder
# 4291                              25 Songs of Christmas
# 4292                                  Poetry Foundation
# 4293                                  Unqualified Media
# 4294                                     The Album Club
# 4295                                  Jimmy Kimmel Live
# 4296                                       Ryan Tillman
# 4297                                      Cameron Fradd
# 4298                                        Ben Cutmore
# 4299                                          Red Scare
# 4300                                 Imploding Fictions
# 4301                             Dr. Scott & Dr. Shiloh
# 4302                                        iHeartRadio
#
#                         genre  \
# 0                      Comedy
# 1                   Education
# 2                     History
# 3                   TV & Film
# 4                        Arts
# 5                  True Crime
# 6                     Science
# 7                   Education
# 8                   TV & Film
# 9                  True Crime
# 10                   Business
# 11          Society & Culture
# 12                    Science
# 13                    History
# 14                      Music
# 15                   Business
# 16                 Government
# 17                    Fiction
# 18                     Comedy
# 19                    Leisure
# 20                    Science
# 21                    History
# 22                     Sports
# 23              Kids & Family
# 24                    History
# 25                    Science
# 26                    Leisure
# 27          Society & Culture
# 28                      Music
# 29           Health & Fitness
# ...                       ...
# 4273        Society & Culture
# 4274  Religion & Spirituality
# 4275            Kids & Family
# 4276                     News
# 4277                    Music
# 4278  Religion & Spirituality
# 4279                  Fiction
# 4280                     Arts
# 4281                Education
# 4282            Kids & Family
# 4283                     News
# 4284                  History
# 4285                     Arts
# 4286  Religion & Spirituality
# 4287                     Arts
# 4288                  Leisure
# 4289  Religion & Spirituality
# 4290                     News
# 4291                    Music
# 4292                     Arts
# 4293                   Comedy
# 4294                    Music
# 4295                TV & Film
# 4296               Government
# 4297  Religion & Spirituality
# 4298                  History
# 4299        Society & Culture
# 4300                  Fiction
# 4301               True Crime
# 4302        Society & Culture
#
#                                             description  num_episodes  rating  \
# 0     Comedians Yannis Pappas and Chris Distefano go...          98.0     4.9
# 1     The award-winning Curiosity Daily podcast from...         300.0     4.8
# 2     A boozy weekly podcast about mythology, legend...         161.0     4.8
# 3     The Soundtrack Show is a weekly look at film s...          67.0     4.9
# 4     Brandon Sanderson, Mary Robinette Kowal, Howar...          58.0     4.7
# 5     July 4, 2009. Former NFL quarterback Steve McN...          10.0     4.3
# 6               Science news and highlights of the week          13.0     4.5
# 7     Every Monday morning Jeff Sanders is here to h...         300.0     4.8
# 8     A podcast devoted to the discussion and dissec...         110.0     4.9
# 9     In October 1989, a 10-year old girl went missi...           6.0     4.6
# 10    Podcast weblog featuring the investment princi...          15.0     4.8
# 11    Journalist and bestselling author Michael Lewi...           9.0     4.4
# 12    This podcast is about strange medicine. I will...          64.0     4.7
# 13    Myths endure for a reason. This episodic audio...          55.0     4.8
# 14    The Coolest Podcast In The World.Hosted by Ada...         250.0     4.6
# 15    Veteran TV writers Liz Craft and Sarah Fain de...         134.0     4.9
# 16    Listen to the ABA Journal Podcasts for analysi...         200.0     4.3
# 17    Nobilis writes erotic science fiction stories ...         280.0     3.7
# 18    A comedy podcast featuring dramatic readings o...          61.0     4.9
# 19    A panel of horticultural experts answer garden...           4.0     4.7
# 20    Lecture audio from this course in Pathophysiol...         172.0     4.8
# 21    Interviews, musings and extra material from th...           8.0     4.8
# 22    CBS Sports’ official college basketball podcas...         300.0     4.6
# 23    Eleanor Amplified is an adventure series for t...          40.0     4.6
# 24    The history of everything. Veteran award-winni...          85.0     4.9
# 25    “Truer, but also darker.” This is the real ori...          13.0     3.8
# 26    The Sustainable Minimalists Podcast is where s...          98.0     4.7
# 27    Get ready to experience a side of Dr. Phil McG...          51.0     4.4
# 28    There is a rumor going around that classical m...         269.0     4.8
# 29    Nonstop, one-hour, high-energy workout music m...         274.0     4.7
# ...                                                 ...           ...     ...
# 4273  Catlick is the lost story of how spies, villai...           6.0     4.8
# 4274  Welcome to the weekly podcast of Elevation Chu...          99.0     4.9
# 4275  Through conversations and interviews, Christin...         182.0     4.7
# 4276  Tony Kornheiser and Michael Wilbon face off in...         199.0     4.5
# 4277  This classical music podcast explores the hist...          38.0     4.4
# 4278  The BEMA Podcast is a walk-through of the cont...         145.0     4.9
# 4279  The Leviathan Chronicles is a sci-fi podcast t...          71.0     4.6
# 4280  The OFFICIAL Mr. Creepy Pasta's Creepypasta St...         250.0     4.9
# 4281  Patient stories from Intensive Dietary Managem...          26.0     4.7
# 4282  Pregnancy Confidential is a series of 32 podca...          32.0     4.3
# 4283  The Lawfare Podcast features discussions with ...          99.0     4.8
# 4284  Linda Taylor was a con artist, a kidnapper, ma...          22.0     4.1
# 4285  Snap Judgment (Storytelling, with a BEAT) mixe...         185.0     4.7
# 4286  Great Stories. Tough Issues. Grace in the Real...           3.0     4.9
# 4287  All the Books! is a weekly show of recommendat...         300.0     4.7
# 4288  Welcome to The Poker Coaching Podcast, hosted ...         286.0     4.8
# 4289  The Craig Groeschel Leadership Podcast offers ...          64.0     4.9
# 4290  Entertaining Daily Politics, Award Winning Lon...          25.0     4.7
# 4291  This is a podcast about Christmas, Music, and ...          18.0     4.6
# 4292  Producer Helena de Groot explores the diverse ...          94.0     4.7
# 4293  Relationship advice from completely unqualifie...         215.0     4.4
# 4294  The Album Club takes you deep into some of the...          67.0     4.6
# 4295  The official Jimmy Kimmel Live! YouTube Channe...          50.0     3.6
# 4296  The goal of the #ITSNEEDED Podcast is to bridg...          31.0     5.0
# 4297  Among The Lilies is the show for ladies who ar...          98.0     4.9
# 4298  Bi-weekly narratives on the unsolved and the u...          72.0     4.9
# 4299  Red Scare is a cultural commentary podcast hos...          99.0     4.0
# 4300  The Amelia Project is a secret agency that fak...          39.0     4.9
# 4301  An L.A. based podcast brought to you by two fo...          36.0     4.8
# 4302  A multiracial mix of queer writers talk about ...          84.0     4.8
#
#       num_reviews                                               link  \
# 0          1300.0  https://podcasts.apple.com/us/podcast/history-...
# 1           428.0  https://podcasts.apple.com/us/podcast/curiosit...
# 2          1200.0  https://podcasts.apple.com/us/podcast/spirits/...
# 3           879.0  https://podcasts.apple.com/us/podcast/the-soun...
# 4           775.0  https://podcasts.apple.com/us/podcast/writing-...
# 5          1500.0  https://podcasts.apple.com/us/podcast/steve-mc...
# 6           110.0  https://podcasts.apple.com/us/podcast/the-scie...
# 7           587.0  https://podcasts.apple.com/us/podcast/the-5-am...
# 8          4600.0  https://podcasts.apple.com/us/podcast/race-cha...
# 9           228.0  https://podcasts.apple.com/us/podcast/amy-shou...
# 10          138.0  https://podcasts.apple.com/us/podcast/boglehea...
# 11         6000.0  https://podcasts.apple.com/us/podcast/against-...
# 12          251.0  https://podcasts.apple.com/us/podcast/stat/id1...
# 13         3400.0  https://podcasts.apple.com/us/podcast/mytholog...
# 14         2200.0  https://podcasts.apple.com/us/podcast/no-jumpe...
# 15         1900.0  https://podcasts.apple.com/us/podcast/happier-...
# 16           16.0  https://podcasts.apple.com/us/podcast/aba-jour...
# 17           84.0  https://podcasts.apple.com/us/podcast/nobilis-...
# 18         1600.0  https://podcasts.apple.com/us/podcast/beach-to...
# 19          102.0  https://podcasts.apple.com/us/podcast/gardener...
# 20          107.0  https://podcasts.apple.com/us/podcast/biology-...
# 21         4300.0  https://podcasts.apple.com/us/podcast/dan-carl...
# 22         1400.0  https://podcasts.apple.com/us/podcast/cbs-spor...
# 23         1000.0  https://podcasts.apple.com/us/podcast/eleanor-...
# 24          476.0  https://podcasts.apple.com/us/podcast/the-podg...
# 25         2100.0  https://podcasts.apple.com/us/podcast/moonrise...
# 26          156.0  https://podcasts.apple.com/us/podcast/the-sust...
# 27         9400.0  https://podcasts.apple.com/us/podcast/phil-in-...
# 28          362.0  https://podcasts.apple.com/us/podcast/classica...
# 29          820.0  https://podcasts.apple.com/us/podcast/podrunne...
# ...           ...                                                ...
# 4273        333.0  https://podcasts.apple.com/us/podcast/catlick/...
# 4274        907.0  https://podcasts.apple.com/us/podcast/elevatio...
# 4275        184.0  https://podcasts.apple.com/us/podcast/edit-you...
# 4276       5400.0  https://podcasts.apple.com/us/podcast/pti/id14...
# 4277         72.0  https://podcasts.apple.com/us/podcast/the-grea...
# 4278        378.0  https://podcasts.apple.com/us/podcast/the-bema...
# 4279       1800.0  https://podcasts.apple.com/us/podcast/the-levi...
# 4280       1200.0  https://podcasts.apple.com/us/podcast/mrcreepy...
# 4281        881.0  https://podcasts.apple.com/us/podcast/the-obes...
# 4282        279.0  https://podcasts.apple.com/us/podcast/pregnanc...
# 4283       4200.0  https://podcasts.apple.com/us/podcast/the-lawf...
# 4284       1100.0  https://podcasts.apple.com/us/podcast/slate-pr...
# 4285       7800.0  https://podcasts.apple.com/us/podcast/snap-jud...
# 4286        134.0  https://podcasts.apple.com/us/podcast/sole-pod...
# 4287        884.0  https://podcasts.apple.com/us/podcast/all-the-...
# 4288        188.0  https://podcasts.apple.com/us/podcast/the-poke...
# 4289       5800.0  https://podcasts.apple.com/us/podcast/craig-gr...
# 4290       2200.0  https://podcasts.apple.com/us/podcast/the-majo...
# 4291         14.0  https://podcasts.apple.com/us/podcast/25-songs...
# 4292        220.0  https://podcasts.apple.com/us/podcast/poetry-o...
# 4293       9000.0  https://podcasts.apple.com/us/podcast/anna-far...
# 4294        118.0  https://podcasts.apple.com/us/podcast/the-albu...
# 4295         30.0  https://podcasts.apple.com/us/podcast/jimmy-ki...
# 4296        234.0  https://podcasts.apple.com/us/podcast/itsneede...
# 4297        658.0  https://podcasts.apple.com/us/podcast/among-th...
# 4298        287.0  https://podcasts.apple.com/us/podcast/dark-his...
# 4299       1200.0  https://podcasts.apple.com/us/podcast/red-scar...
# 4300        386.0  https://podcasts.apple.com/us/podcast/the-amel...
# 4301        151.0  https://podcasts.apple.com/us/podcast/l-a-not-...
# 4302       1100.0  https://podcasts.apple.com/us/podcast/food-4-t...
#
#                                          episode_titles  \
# 0     robert moses was wild kinsey was wild prohibit...
# 1     maps as weapons and art w justin fornal and em...
# 2     jacheongbi multimedia mythmaking with carmen m...
# 3     season  intermission the nightmare before chri...
# 4     economics realism vs ruleofcool sequencing you...
# 5     epilogue the homicidecold case unit the widow ...
# 6     climate in crisis wildfires and winds in calif...
# 7     the  strategy to defy fear and define your des...
# 8     hot goss  slanderous libel tips from glsen and...
# 9     loose ends siblings besties the lineup amy goe...
# 10    episode  eric balchunas host rick ferri episod...
# 11    against the rules presents cautionary tales bo...
# 12    dr michael swango  pt one placebo effect rig l...
# 13    listen first dog tales a parcast original seri...
# 14    the no jumper show ep the jem wolfie interview...
# 15    ep  the importance of mahjong bonus episode li...
# 16    aba journal legal rebels  diversity in the leg...
# 17    ep  we sail by night by gustavo bondoni ep  a ...
# 18    golf courses in des moines ia between you and ...
# 19    north wessex downs the chilterns calne wiltshi...
# 20    biology  lectures on pathophysiology biology  ...
# 21    ep caesar at hastings ep hardcore history on f...
# 22    michigan stateseton hall best game of season s...
# 23    extra s sneak peek shhh the road trip edition ...
# 24    bad girls evil women in history serial killers...
# 25    the dark moon magnificent desolation the beyon...
# 26    less is more practical selfcare during the hol...
# 27    relationship reality check how much fun are yo...
# 28    classical classroom episode  nicholas mcgegan ...
# 29    bpm  ahead of the curve bpm  go juice bpm  spr...
# ...                                                 ...
# 4273  e black or white e slash and dash e the man in...
# 4274  needers amp feeders the lazarus factor god of ...
# 4275  episode  navigating divorce  single parenthood...
# 4276  making a return out for now shocking things ch...
# 4277  the life of johannes brahms pt  summer idylls ...
# 4278  galatians  pauls gospel the epilogue calling o...
# 4279  leviathan update soapbox chapter chapter chapt...
# 4280  happy halloween from the gas station by jack t...
# 4281  energy balance kidney disease update selfforgi...
# 4282  pregnancy week   omg im pregnant pregnancy wee...
# 4283  quite a week the lawfare podcast bonus edition...
# 4284  bonus  the queen an audiobook preview bonus  t...
# 4285  return to kuku island  snap classic the lamb t...
# 4286  race religion amp identity  fatherless no more...
# 4287  all the backlist november new releases and mor...
# 4288  wph  triple barrel bluff from  ladies night ca...
# 4289  building the middle qampa with crossfit champi...
# 4290  stone convicted impeachment marches on amp wha...
# 4291  season   episode season   episode season   epi...
# 4292  a presence in the sky the garden we share afte...
# 4293  chris sullivan tig notaro elisha cuthbert busy...
# 4294  ep   ramones  rocket to russia ep  pj harvey  ...
# 4295  this week in unnecessary censorship antonio ba...
# 4296  episode   power of relationships episode   clo...
# 4297  preemie miracles w christine malone matt fradd...
# 4298  the yatton demoniac george lukins the sarah du...
# 4299  bore carnival teaser pest control greta fg thu...
# 4300  richard  season  finale ant cleo cole niseag b...
# 4301  killer nurses the fear of clowns intimate part...
# 4302  are you committed to this podcast lets talk ab...
#
#                                    episode_descriptions
# 0     the boys discuss robert moses wild the hyenas ...
# 1     explorers justin fornal and emiliano ruprah fr...
# 2     this story seems like we lifted it straight ou...
# 3     season  intermission  learn more about your ad...
# 4     your hosts brandon dan howard and mahtab  econ...
# 5     vincent hill presents evidence before a nashvi...
# 6     pledges to reduce greenhouse gas emissions are...
# 7     episode show notes jeffsanderscom  learn more ...
# 8     alaska and willam dive deep into gossip conjec...
# 9     what will it really take to solve the case of ...
# 10    eric balchunas is the senior etf analyst at bl...
# 11    a new show from pushkin industries cautionary ...
# 12    the beginning  dr michael swango was convicted...
# 13    theyre fourlegged full of love and often times...
# 14    adam tells the podcast about the childrens you...
# 15    with development season at peak intensity liz ...
# 16    the year  was hailed as the year of women in l...
# 17    this months patronfunded story is a straight e...
# 18    golfer emoji golfer emoji golfer emoji holeino...
# 19    peter gibbs and the panel are in the north wes...
# 20    todays lecture introduces infections of the re...
# 21    could militaries separated by ten centuries co...
# 22    myles powells  points werent enough to get set...
# 23    huh what nope nothing to see here not buying i...
# 24    you thought guys could be wicked wow check out...
# 25    apollo  lifts off from earth fulfilling but al...
# 26    is it me or do we often forget selfcare during...
# 27    dr phil is joined by leading human sexuality e...
# 28    conductor nicholas mcgegan of san francisco ph...
# 29    a highenergy workout mix that drops a psy tran...
# ...                                                 ...
# 4273  local authorities arrive at a scene so gruesom...
# 4274  to support this ministry and help us continue ...
# 4275  to say that navigating divorce and single pare...
# 4276  frank isola and michael wilbon react to myles ...
# 4277  in ep  we see johannes brahms complete his ado...
# 4278  marty solomon and brent billings examine the f...
# 4279  a new leviathan soapbox to explain what has be...
# 4280  dude your town really sucks  the author httpsw...
# 4281  dr fung explains why the caloriecentric model ...
# 4282  in this episode well cover all you need to kno...
# 4283  this week roger stone was convicted on seven c...
# 4284  listen to the first chapter of the audiobook v...
# 4285  a woman revisits remote indonesian islands whe...
# 4286  what role does skin color play in identity for...
# 4287  this week jenn discusses two great older books...
# 4288  the newest pokercoachingcom coach lexy gavin f...
# 4289  as your organization grows the levels of manag...
# 4290  sam hosts emma vigeland from the young turks e...
# 4291  snowmen sing along if you want shake a hand sh...
# 4292  fanny howe gives away the secret to being cava...
# 4293  chris sullivan this is us the knick stranger t...
# 4294  this episode explores forest hills finest punk...
# 4295  once again weve bleeped and blurred all the we...
# 4296  ryan and aj discuss the importance of relation...
# 4297  i cant tell you ladies how excited i am about ...
# 4298  sir when you can spare room in your gazette i ...
# 4299  the ladies discuss the online ya wars the cuts...
# 4300  i always obey the dice   episode  season  fina...
# 4301  dr scott and dr shiloh delve into the world of...
# 4302  its cuffing season and while ur thots love a g...
#
# [4303 rows x 10 columns]

# %%
total_number_podcast = len(podcasts_df.index)
print('Total Number of Podcasts: ' + str(total_number_podcast))
# Out:
# Total Number of Podcasts: 4303

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# The DataFrame above was constructed by scraping all podcasts listed as "Popular Podcasts" from each major genre on iTunes. The DataFrame contains 4303 podcasts (after dropping podcasts that had 'NA' values). Here's a breakdown of each genre:

# %%
podcasts_df['genre'].value_counts()
# Out:
# Sports                     237
# Arts                       235
# Kids & Family              235
# News                       233
# True Crime                 232
# Comedy                     229
# Fiction                    227
# Religion & Spirituality    227
# Society & Culture          226
# Science                    225
# Health & Fitness           224
# TV & Film                  224
# Leisure                    224
# History                    224
# Technology                 223
# Business                   223
# Music                      222
# Government                 220
# Education                  213
# Name: genre, dtype: int64

# %%
podcasts_df['genre'].value_counts().plot(kind='barh', figsize=(14, 12))
plt.xlabel("# of Podcasts", labelpad=14)
plt.ylabel("Genre", labelpad=14)
plt.style.use('fivethirtyeight')
plt.title("Fig. 1: Number of 'Popular Podcasts' Per Genre", y=1.05)
# Out:
# Text(0.5, 1.05, "Fig. 1: Number of 'Popular Podcasts' Per Genre")

# %% [markdown]
# From the graph above, we can tell that Apple lists roughly the same number (~235) of "Popular Podcasts" per genre. So, for a given individual who has a favorite podcast in a particular genre, it becomes very difficult for that individual to search for similar, enjoyable podcasts. A user is faced with the burden of navigating through a large volume of podcasts not only within a specfic genre but across genres as well just to find something that they might like.

# %%
genre = podcasts_df[['genre', 'rating', 'num_reviews']]
genre.groupby('genre').mean()
# Out:
#                            rating  num_reviews
# genre
# Arts                     4.627234  1247.480851
# Business                 4.659641  1531.919283
# Comedy                   4.765939  6568.397380
# Education                4.648357   774.361502
# Fiction                  4.648899  1085.176211
# Government               4.658636   196.709091
# Health & Fitness         4.696875  1269.455357
# History                  4.653125  1474.571429
# Kids & Family            4.637872   614.302128
# Leisure                  4.749107   713.473214
# Music                    4.677027   651.783784
# News                     4.522318  3899.343348
# Religion & Spirituality  4.800000  1514.502203
# Science                  4.569333   916.524444
# Society & Culture        4.659292  4287.566372
# Sports                   4.677637  2381.075949
# TV & Film                4.570982  1200.388393
# Technology               4.613004   486.923767
# True Crime               4.539224  4508.719828

# %% [markdown]
# The above table shows the the average rating (out of 5) among all "Popular Podcasts" on iTunes per genre. The range of the average ratings is roughly 0.23, which is too small to say anything about a dominating, popular category. Also, it makes sense for iTunes to only display podcasts with high ratings on their "Popular Podcasts" page.
#
# So, it doesn't make logical sense to recommend a podcast genre to a user solely based on ratings because all the ratings are relatively high. Also, just recommending a podcast genre, once again, isn't helpful to a user becasue not only will the user already know what genre(s) he likes, but also needs to navigate roughly 235 popular podcasts in any given genre to find a favorite.

# %%
genre.groupby('genre')['num_reviews'].mean().plot(kind='bar', figsize=(14, 12))
plt.xlabel("Genre", labelpad=14)
plt.ylabel("Avg # of Reviews", labelpad=14)
plt.style.use('fivethirtyeight')
plt.title("Fig. 2: Avg # of Reviews of Per Genre", y=1.05)
# Out:
# Text(0.5, 1.05, 'Fig. 2: Avg # of Reviews of Per Genre')

# %%
genre.groupby('genre')['num_reviews'].median().plot(kind='bar', figsize=(14, 12))
plt.xlabel("Genre", labelpad=14)
plt.ylabel("Median of Reviews", labelpad=14)
plt.style.use('fivethirtyeight')
plt.title("Fig. 3: Median of Reviews of Per Genre", y=1.0)
# Out:
# Text(0.5, 1.0, 'Fig. 3: Median of Reviews of Per Genre')

# %% [markdown]
# Both Fig. 2 and Fig. 3 show us the average number of reviews and median number of reviews per genre, respectively. Intuitively, it would make sense that using the average number of reviews is a skewed summary statistic because of dominating podcasts in any given genre (i.e. The Joe Rogan Experience podcast has 127,500 reviews). Therefore, it makes more sense to observe Fig. 3, which shows the the median number of reviews per genre.
#
# Looking at Fig. 3, we can see that the top 3 highly reviewed podcast genres are Comedy, Society & Culture, and News. I am making the assumption that any highly reviewed podcast genre is a genre that is popular, relevant, and active.
#
# Although, Fig. 3 gives us insight as to what podcast genres are "buzzing," it doesn't help with the fact of of recommending podcasts to a user for some of the following reasons:
#
# 1. Say a user likes a specific "Comedy" podcast. He knows he likes the "Comedy" genre and wants to find a new "Comedy" podcast. The average rating doesn't really help because all the "Popular Podcasts" on iTunes is rated pretty high and too many reviews to read.
#
# 2. Say a user likes a specific "Government" podcast. The "Government" genre doesn't really have an active community with many people reviewing podcasts, so the user has no way of knowing what podcast to listen to next, and he is not willing to scour through the ~240 "Popular Podcasts" listed on the "Government" podcast page.
#
# 3. Say a user likes a specfic podcast in some genre. He wants to find a new podcast to listen to and he doesn't care about the genre. He just wants something that is similar to what he has been listening to. What can he do?
#
# All of these are possible situations a user can run into. So, can we build a model to recommend a podcast to a user based on what he podcast he likes or what he listened to in the past?

# %% [markdown]
# # Understanding Genres

# %%
import sys
sys.path.insert(0, '../scripts')

import nltk
import heapq
from collections import Counter
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize
from collections import Counter
from PIL import Image
from wordcloud import WordCloud, ImageColorGenerator
from get_podcast_ep_data import clean_description, clean_title

# %% [markdown]
# ## Looking at Different Genres

# %%
def topKFrequent(tokenized_text, k): 
   
    count = Counter(tokenized_text)   
    
    return heapq.nlargest(k, count.keys(), key=count.get)

def get_genre_description_text(genre):
    genre_text = " ".join(clean_description(description) for description in podcasts_df[podcasts_df.genre==genre].description)
    
    tokenized_text = nltk.word_tokenize(genre_text)
    
    top20 = topKFrequent(tokenized_text, 20)
    updated_stopwords = set(nltk.corpus.stopwords.words('english'))
    updated_stopwords.update(common_words)
    updated_stopwords.update(top20)
    
    tokenized_text = [word for word in tokenized_text if word not in updated_stopwords]
    
    genre_text = ' '.join(tokenized_text)
    
    return genre_text

common_words = ['podcast', 'podcasts', 'every', 'new', 'weekly', 
                'stories', 'story', 'episode', 'episodes', 'listen', 
                'host', 'hosted', 'join', 'monday', 'tuesday', 'wednesday',
                'thursday', 'friday', 'saturday', 'sunday']

# %%
arts_text = get_genre_description_text('Arts')
kids_fam_text = get_genre_description_text('Kids & Family')
news_text = get_genre_description_text('News')
crime_text = get_genre_description_text('True Crime')
comedy_text = get_genre_description_text('Comedy')
religon_text = get_genre_description_text('Religion & Spirituality')
fiction_text = get_genre_description_text('Fiction')
culture_text = get_genre_description_text('Society & Culture')
science_text = get_genre_description_text('Science')
history_text = get_genre_description_text('History')
health_text = get_genre_description_text('Health & Fitness')
lesiure_text = get_genre_description_text('Leisure')
tv_film_text = get_genre_description_text('TV & Film')
tech_text = get_genre_description_text('Technology')
business_text = get_genre_description_text('Business')
music_text = get_genre_description_text('Music')
gov_text = get_genre_description_text('Government')
edu_text = get_genre_description_text('Education')

# %%
all_desc_text = arts_text + " " + kids_fam_text + " " + news_text + " " + crime_text + " " + comedy_text + " " + religon_text + " " + fiction_text + " " + culture_text + " " + science_text + " " + history_text + " " + health_text + " " + lesiure_text + " " + tv_film_text + " " + tech_text + " " + business_text + " " + music_text + " " + gov_text + " " + edu_text

# %%
def show_wordcloud(data):
    wordcloud = WordCloud(
        background_color='white',
        max_words=200,
        max_font_size=40, 
        scale=3,
        random_state=1 # chosen at random by flipping a coin; it was heads
    ).generate(data)

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')
    
    plt.style.use('ggplot')
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.show()

# %%
show_wordcloud(all_desc_text)

# %% [markdown]
# ##### Fig. 1: Word Cloud of All Genres

# %% [markdown]
# The word cloud is an interesting visualization of the descriptions of all the "Popular Podcasts" across all the genres. The bigger words indicate what words are being used most frequently, universally across all podcast descriptions.
#
# Now let's take a look at how the word cloud changes if we solely foucs on the "Comedy" genre

# %%
show_wordcloud(comedy_text)

# %% [markdown]
# ##### Fig 2. Comedy Word Cloud

# %% [markdown]
# Looking at the "Comedy" genre word cloud, we can easily see some differences from the word cloud for all genres. Some common themes across the comedy genre include: "advice", "interview(s)", "relationship", "sex", and "conversation.". This tell us there are some common theme that are specific to certain genres.
#
# Let's look at one more genre: "News" just to see some interesting differences.

# %%
show_wordcloud(news_text)

# %% [markdown]
# ##### Fig. 3 News Word Cloud

# %% [markdown]
# # Similarites Across Different Genres

# %% [markdown]
# From looking at some word clouds from different genres, we can see some of the popular words that circulate among certain genres. However, what if there are similarites across different genres, and how can we account for such similarites so that we can provide meaningful podcast recommendations across all genres to a user.
#
# Hence, we need to investigate how genres are related and make sure that if a user likes a particular podcast within a specific genre that there not ignoring similar, likeable podcasts in different genres.

# %% [markdown]
# ## Estimating Degree of Similarities between Genre Description Text

# %%
import gensim 
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from scipy.spatial import distance
from gensim.models import Word2Vec
porter = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# %%
def stemSentence(sentence):
    token_words = word_tokenize(sentence)
    stem_output = ' '.join([porter.stem(w) for w in token_words])
    
    return stem_output

def lemSentence(sentence):
    token_words = word_tokenize(sentence)
    lemmatized_output = ' '.join([lemmatizer.lemmatize(w) for w in token_words])
    
    return lemmatized_output

# %% [markdown]
# For the purposes of computational complexity and sake of simplicity, let's only look at the following 4 genres:
# 1. Comedy
# 2. News
# 3. Society & Culture (S&C)
# 4. Government

# %% [markdown]
# ### Jaccard Similarity

# %%
def get_jaccard_sim(str1, str2):
    str1 = lemSentence(str1)
    str2 = lemSentence(str2)
    a = set(str1.split()) 
    b = set(str2.split())
    c = a.intersection(b)
    return round((float(len(c)) / (len(a) + len(b) - len(c))), 3)

# %%
print("Jaccard Similarity between Comedy and S&C = " + str(get_jaccard_sim(comedy_text, culture_text)))
print("Jaccard Similarity between Comedy and News = " + str(get_jaccard_sim(comedy_text, news_text)))
print("Jaccard Similarity between S&C and News = " + str(get_jaccard_sim(culture_text, news_text)))
print("Jaccard Similarity between Comedy and Government = " + str(get_jaccard_sim(comedy_text, gov_text)))
print("Jaccard Similarity between News and Government = " + str(get_jaccard_sim(news_text, gov_text)))
print("Jaccard Similarity between S&C and Government = " + str(get_jaccard_sim(culture_text, gov_text)))
# Out:
# Jaccard Similarity between Comedy and S&C = 0.221
# Jaccard Similarity between Comedy and News = 0.201
# Jaccard Similarity between S&C and News = 0.228
# Jaccard Similarity between Comedy and Government = 0.195
# Jaccard Similarity between News and Government = 0.243
# Jaccard Similarity between S&C and Government = 0.236

# %% [markdown]
# ### Cosine Similarity + CountVectorizer Method

# %%
def get_cosine_sim(str1, str2):
    
    str1 = lemSentence(str1)
    str2 = lemSentence(str2)
    
    # sentences to list
    allsentences = [str1 , str2]
    
    # text to vector
    vectorizer = CountVectorizer()
    all_sentences_to_vector = vectorizer.fit_transform(allsentences)
    text_to_vector_v1 = all_sentences_to_vector.toarray()[0].tolist()
    text_to_vector_v2 = all_sentences_to_vector.toarray()[1].tolist()
    
    # distance of similarity
    cosine = distance.cosine(text_to_vector_v1, text_to_vector_v2)
    cosine_sim = round((1-cosine), 3)
    
    return cosine_sim

# %%
print("Cosine Similarity between Comedy and S&C = " + str(get_cosine_sim(comedy_text, culture_text)))
print("Cosine Similarity between Comedy and News = " + str(get_cosine_sim(comedy_text, news_text)))
print("Cosine Similarity between S&C and News = " + str(get_cosine_sim(culture_text, news_text)))
print("Cosine Similarity between Comedy and Government = " + str(get_cosine_sim(comedy_text, gov_text)))
print("Cosine Similarity between News and Government = " + str(get_cosine_sim(news_text, gov_text)))
print("Cosine Similarity between S&C and Government = " + str(get_cosine_sim(culture_text, gov_text)))
# Out:
# Cosine Similarity between Comedy and S&C = 0.724
# Cosine Similarity between Comedy and News = 0.575
# Cosine Similarity between S&C and News = 0.662
# Cosine Similarity between Comedy and Government = 0.494
# Cosine Similarity between News and Government = 0.616
# Cosine Similarity between S&C and Government = 0.593

# %% [markdown]
# ### Cosine Similarity + TFIDF

# %%
def get_cosine_tfidf_sim(str1, str2):
    
    str1 = lemSentence(str1)
    str2 = lemSentence(str2)
    
    # sentences to list
    allsentences = [str1 , str2]
    
    # text to vector
    vectorizer = TfidfVectorizer()
    all_sentences_to_vector = vectorizer.fit_transform(allsentences)
    text_to_vector_v1 = all_sentences_to_vector.toarray()[0].tolist()
    text_to_vector_v2 = all_sentences_to_vector.toarray()[1].tolist()
    
    # distance of similarity
    cosine = distance.cosine(text_to_vector_v1, text_to_vector_v2)
    cosine_sim = round((1-cosine), 3)
    
    return cosine_sim

# %%
print("Cosine Similarity + TFIDF between Comedy and S&C = " + str(get_cosine_tfidf_sim(comedy_text, culture_text)))
print("Cosine Similarity + TFIDF between Comedy and News = " + str(get_cosine_tfidf_sim(comedy_text, news_text)))
print("Cosine Similarity + TFIDF between S&C and News = " + str(get_cosine_tfidf_sim(culture_text, news_text)))
print("Cosine Similarity + TFIDF between Comedy and Government = " + str(get_cosine_tfidf_sim(comedy_text, gov_text)))
print("Cosine Similarity + TFIDF between News and Government = " + str(get_cosine_tfidf_sim(news_text, gov_text)))
print("Cosine Similarity + TFIDF between S&C and Government = " + str(get_cosine_tfidf_sim(culture_text, gov_text)))
# Out:
# Cosine Similarity + TFIDF between Comedy and S&C = 0.669
# Cosine Similarity + TFIDF between Comedy and News = 0.502
# Cosine Similarity + TFIDF between S&C and News = 0.599
# Cosine Similarity + TFIDF between Comedy and Government = 0.393
# Cosine Similarity + TFIDF between News and Government = 0.554
# Cosine Similarity + TFIDF between S&C and Government = 0.539

# %% [markdown]
# ### Cosine Similarity with GloVe Embedding

# %%
gloveFile = '../glove/glove.6b.100d.txt'

# %%
with open(gloveFile, encoding="utf8" ) as f:
    content = f.readlines()
    model = {}
    for line in content:
        splitLine = line.split()
        word = splitLine[0]
        embedding = np.array([float(val) for val in splitLine[1:]])
        model[word] = embedding

# %%
def cosine_sim_wordembedding_method(str1, str2):
    
    str1_wordList = list(set([w for w in str1.split()]))
    str2_wordList = list(set([w for w in str2.split()]))
    
    vector_1 = np.mean([model[word] for word in str1_wordList if word in model],axis=0)
    vector_2 = np.mean([model[word] for word in str2_wordList if word in model],axis=0)
    
    cosine = distance.cosine(vector_1, vector_2)
    cosine_sim = round((1-cosine), 3)
    
    return cosine_sim

# %%
print("Cosine Similarity w/GloVe embedding + SIF between Comedy and S&C = " + str(cosine_sim_wordembedding_method(comedy_text, culture_text)))
print("Cosine Similarity w/GloVe embedding + SIF between Comedy and News = " + str(cosine_sim_wordembedding_method(comedy_text, news_text)))
print("Cosine Similarity w/GloVe embedding + SIF between S&C and News = " + str(cosine_sim_wordembedding_method(culture_text, news_text)))
print("Cosine Similarity w/GloVe embedding + SIF between Comedy and Government = " + str(cosine_sim_wordembedding_method(comedy_text, gov_text)))
print("Cosine Similarity w/GloVe embedding + SIF between News and Government = " + str(cosine_sim_wordembedding_method(news_text, gov_text)))
print("Cosine Similarity w/GloVe embedding + SIF between S&C and Government = " + str(cosine_sim_wordembedding_method(culture_text, gov_text)))
# Out:
# Cosine Similarity w/GloVe embedding + SIF between Comedy and S&C = 0.988
# Cosine Similarity w/GloVe embedding + SIF between Comedy and News = 0.974
# Cosine Similarity w/GloVe embedding + SIF between S&C and News = 0.985
# Cosine Similarity w/GloVe embedding + SIF between Comedy and Government = 0.941
# Cosine Similarity w/GloVe embedding + SIF between News and Government = 0.98
# Cosine Similarity w/GloVe embedding + SIF between S&C and Government = 0.966
